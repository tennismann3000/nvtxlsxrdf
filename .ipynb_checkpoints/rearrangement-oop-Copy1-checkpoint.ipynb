# %%
import pandas as pd
import rdflib
import numpy as np
from rdflib import Graph, Namespace, URIRef, BNode, Literal, RDF, util
from rdflib.namespace import NamespaceManager
import datetime
pd.options.display.max_colwidth = 144

# %%
time = str(datetime.datetime.now().strftime('%Y_%m_%d'))

# %%
def merge_columns(sheet, mapping, origin):
    ## noch ein bisschen sauberer wäre gut, zeilenumbruch nach beschreibung vllt und personennamen in richtiger schreibweise
    ## bei result = texts müssten Autoren noch mit den Labels der Personen, auf die verwiesen wird, versehen werden
    
    df = sheet.tdf
    
    if origin == "zeitraum":
        col1 = mapping["zeitraum1"]
        col2 = mapping["zeitraum2"]
        col3 = mapping["zeitraum"]
        df.loc[df[col1].notna() & df[col2].notna(), col3] = "timespan_" + df[mapping["ID"]] + "_" + df[col1].apply(str).str[:4] + "_" + df[col2].apply(str).str[:4]
        df.loc[df[col1].notna() & df[col2].isna(), col3] = "timespan_" + df[mapping["ID"]] + "_" + df[col1].apply(str).str[:4]
        df.loc[df[col1].isna() & df[col2].notna(), col3] = "timespan_" + df[mapping["ID"]] + "_" + df[col2].apply(str).str[:4]
    
    if origin == "season":
        col1 = mapping["season1"]
        col2 = mapping["season2"]
        col3 = mapping["season"]
        df.loc[df[col1].notna() & df[col2].notna(), col3] = "season_" + df[mapping["ID"]] + "_" + df[col1].apply(str).str[:4] + "_" + df[col2].apply(str).str[:4]
        df.loc[df[col1].notna() & df[col2].isna(), col3] = "season_" + df[mapping["ID"]] + "_" + df[col1].apply(str).str[:4]
        df.loc[df[col1].isna() & df[col2].notna(), col3] = "season_" + df[mapping["ID"]] + "_" + df[col2].apply(str).str[:4]
  
    if origin == "description":
        col1 = mapping["description1"]
        col2 = mapping["description2"]
        col3 = mapping["description"]
        df.loc[df[col1].notna() & df[col2].notna(), col3] = df[col1] + " Quelle: " + df[col2]
        df.loc[df[col1].notna() & df[col2].isna(), col3] = df[col1]
        df.loc[df[col1].isna() & df[col2].notna(), col3] = "Quelle: " + df[col2]        
    
    if origin == "texts":
        col1 = mapping["texts1"]
        col2 = mapping["texts2"]
        col3 = mapping["texts"]
        df[col2] = peoplereplace(df[col2])
        df.loc[df[col1].notna() & df[col2].notna(), col3] = "Text(e): " + df[col1] + " Autor(en): " + df[col2]
        df.loc[df[col1].notna() & df[col2].isna(), col3] = "Text(e): " + df[col1]
        df.loc[df[col1].isna() & df[col2].notna(), col3] = "Autor(en): " + df[col2]
        

    if origin == "condition":
        col1 = mapping["condition1"]
        col2 = mapping["condition2"]
        col3 = mapping["condition"]
        df.loc[df[col1].notna() & df[col2].notna(), col3] = "Zustand: " + df[col1] + " Datum Zustandsaufnahme: " + df[col2].apply(str)
        df.loc[df[col1].notna() & df[col2].isna(), col3] = "Zustand: " + df[col1]
        df.loc[df[col1].isna() & df[col2].notna(), col3] = " Datum Zustandsaufnahme: " + df[col2].apply(str)       

    if origin == "institution":
        col1 = mapping["ID"]
        col2 = mapping["institution1"]
        col3 = mapping["institution"]
        df.loc[df[col2].notna(), col3] = df[col1].str.replace("LOC_", "G_")
        
    if origin == "physical": # neue if-Kondition für objekte, die physisch nicht exisitieren
        regexr = "[\s\S]+"
        col1 = mapping["ID"]
        col3 = mapping["physical"]
        
        if sheet.name == "Objekte VIDEOS":
            regexr = "^(vid-[0-9]{3})$"
            df.loc[df[col1].notna() & df[col1].str.match(regexr, na=False), col3] = "phys_" + df[col1]
            
        if sheet.name == "Objekte BILD":
            regexr = "(Negativmappe)|(Mappe \(sonstige\))|(Fotomappe \(Positive\))"
            col2 = "Archivalientyp"
            df.loc[df[col1].notna() & ~df[col2].str.match(regexr, na=False), col3] = "phys_" + df[col1]
        
        if sheet.name == "Objekte TEXT":
            regexr = "(Archivmappe)|(Mappe \(sonstige\))|(Typoskript Sammlung)|(Anderes)|(Plakate)"
            col2 = "Archivalientyp"
            df.loc[df[col1].notna() & ~df[col2].str.match(regexr, na=False), col3] = "phys_" + df[col1]
            
        if sheet.name == "Objekte AUDIO":
            df[col3] = np.nan
        
    if origin == "digital": # neue if-Kondition für objekte, die digital nicht exisitieren
        
 #      col1 = mapping["ID"]
        col3 = mapping["digital"]
        
        df[col3] = np.nan
 #      df.loc[df[col1].notna(), col3] = "digi_" + df[col1]
 #      df[col4] = df[col3]

# %%
def sort_reindex(df, index=None):
    df = (df.sort_values(by=[index])
          .reset_index(drop=True) ## resets index to be continouus            
         )
    return df

# %%
def refreplace(col):
    ## string converter for URIs
    col = col.str.lower()
    col = col.str.replace("ä", "ae")
    col = col.str.replace("ö","oe")
    col = col.str.replace("ü","ue")
    col = col.str.replace("ß","ss")
    col = col.str.replace("!?,\.", "")
    col = col.str.replace("[^a-zA-Z0-9;]", "_")
    col = col.str.replace("-", "_")
    col = col.str.replace("_{2,}", "_")
    col = col.str.strip("_")
    col = col.str.strip()
    return col

# %%
def supersplit(col):
    ## for more convenient str splitting within the columns (expand=false), mainly for splitting all URIs
    if col.any():
        col = col.str.split(";", expand = False)
    return col

# %%
def splitreplace(col):
    ## combines refreplace and supersplit in correct order for they are both always used for any columns containing URIs
    col = refreplace(col)
    col = supersplit(col)
    return col

# %%
def peoplereplace(df):
    ## temporary string beautifier for persons as literal values
    df = df.str.replace("_"," ")
    df = df.str.replace(",", " ")
    df = df.str.replace(";", "; ")
    return df

# %%
def str_to_rdf(column, nsm):
    newlist = []
    for i in column:
        if isinstance(i, list):
            newlistlist = []
            for j in i:
                newlistlist.append(util.from_n3(j, nsm=nsm))
            newlist.append(newlistlist)
        else:
            newlist.append(float("NaN"))
    column = pd.Series(newlist)
    return column

# %%
def mapping_to_dict(mapping):
    mapping_list = []
    merger = pd.DataFrame
    titlekey = pd.DataFrame
    for key,value in mapping.items():
        # value.dropna(subset=["NVTO Property"], inplace=True) # droppt alle Spaltennamen Einträge ohne korrespondierende NVTO Property

        value[['Object Class','NVTO Property']] = value[['Object Class','NVTO Property']].apply(supersplit, axis=1) # splittet alle Spalten mit RDF-Properties oder Classes

        value["NVTO Property"] = str_to_rdf(value["NVTO Property"], nsm) # wandelt die Werte der Spalte in rdflib URIRefs um

        value["Object Class"] = str_to_rdf(value["Object Class"], nsm) # wandelt die Werte der Spalte in rdflib URIRefs um


        merge = (value[['Spaltenname in Tabelle','Merge']].dropna(subset=["Merge"])
                                                        .set_index('Merge').T.to_dict('records')) # merge baut dict zum Mergen von 

        titledict = value.set_index('Spaltenname in Tabelle').T.to_dict('list')
        sheetid = value.loc[value['Merge']=="ID", 'Spaltenname in Tabelle'].iloc[0]
        mapping_list.append(Mapping(sheet = key, #baut Klassenobjekte mit den unten genannten Einträgen
                                    df = value, 
                                    title = value["Spaltenname in Tabelle"], 
                                    rdfp = value["NVTO Property"],
                                    original = value["Merge"],
                                    subj = value["Subject"],
                                    objclass = value["Object Class"],
                                    objtype = value["Object Type"],
                                    merge = merge,
                                    titledict = titledict,
                                    sheetid = sheetid
                                    )
                           )
    return mapping_list

# %%
context = Namespace("http://lod.iti-germany.de/contexts/")
dc = Namespace("http://purl.org/dc/elements/1.1/")
dcterms = Namespace("http://purl.org/dc/terms/")
edm = Namespace("http://www.europeana.eu/schemas/edm/")
foaf = Namespace("http://xmlns.com/foaf/0.1/")
mtt_a = Namespace("http://lod.iti-germany.de/schema/mtt_a/")
nvt = Namespace("http://lod.iti-germany.de/resource/")
nvto = Namespace("http://lod.iti-germany.de/schema/nvto/")
owl = Namespace("http://www.w3.org/2002/07/owl#")
rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
rdfs = Namespace("http://www.w3.org/2000/01/rdf-schema#")
skos = Namespace("http://www.w3.org/2004/02/skos/core#")
wgs84_pos = Namespace("http://www.w3.org/2003/01/geo/wgs84_pos#")

# %%
nsm = NamespaceManager(Graph())
nsm.bind("context", "http://lod.iti-germany.de/contexts/")
nsm.bind("dc", "http://purl.org/dc/elements/1.1/")
nsm.bind("dcterms", "http://purl.org/dc/terms/")
nsm.bind("edm", "http://www.europeana.eu/schemas/edm/")
nsm.bind("foaf", "http://xmlns.com/foaf/0.1/")
nsm.bind("mtt_a", "http://lod.iti-germany.de/schema/mtt_a/")
nsm.bind("nvt", "http://lod.iti-germany.de/resource/")
nsm.bind("nvto", "http://lod.iti-germany.de/schema/nvto/")
nsm.bind("owl", "http://www.w3.org/2002/07/owl#")
nsm.bind("rdf", "http://www.w3.org/1999/02/22-rdf-syntax-ns#")
nsm.bind("rdfs", "http://www.w3.org/2000/01/rdf-schema#")
nsm.bind("skos", "http://www.w3.org/2004/02/skos/core#")
nsm.bind("wgs84_pos", "http://www.w3.org/2003/01/geo/wgs84_pos#")

# %%
def bindbind(graph):
    graph.bind("context", "http://lod.iti-germany.de/contexts/")
    graph.bind("dc", "http://purl.org/dc/elements/1.1/")
    graph.bind("dcterms", "http://purl.org/dc/terms/")
    graph.bind("edm", "http://www.europeana.eu/schemas/edm/")
    graph.bind("foaf", "http://xmlns.com/foaf/0.1/")
    graph.bind("mtt_a", "http://lod.iti-germany.de/schema/mtt_a/")
    graph.bind("nvt", "http://lod.iti-germany.de/resource/")
    graph.bind("nvto", "http://lod.iti-germany.de/schema/nvto/")
    graph.bind("owl", "http://www.w3.org/2002/07/owl#")
    graph.bind("rdf", "http://www.w3.org/1999/02/22-rdf-syntax-ns#")
    graph.bind("rdfs", "http://www.w3.org/2000/01/rdf-schema#")
    graph.bind("skos", "http://www.w3.org/2004/02/skos/core#")
    graph.bind("wgs84_pos", "http://www.w3.org/2003/01/geo/wgs84_pos#")
    return graph

# %%
nvt_ds = rdflib.Dataset()
nvt_ds = bindbind(nvt_ds)
pr_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/productions")
ev_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/events")
vid_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/videos")
text_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/texts")
img_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/images")
aud_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/audio")
person_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/persons")
group_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/groups")
loc_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/locations")
city_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/cities")
country_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/countries")
col_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/collections")
series_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/series")
concept_graph = nvt_ds.graph(identifier="http://lod.iti-germany.de/contexts/concepts")
graph_list = [pr_graph, ev_graph, vid_graph, text_graph, img_graph, aud_graph, person_graph, group_graph, loc_graph, city_graph, country_graph, col_graph, series_graph, concept_graph]

# %%
nvt_master = pd.read_excel('./NVT_Metadatentabelle_MASTER_0609.xlsm', sheet_name=None)
nvt_master_old = pd.read_excel('./NVT_Metadatentabelle_MASTER_0609test.xlsm', sheet_name=None)

# %%
#master_val = [i for i in nvt_master.values()]
#master_val_old = [i for i in nvt_master_old.values()]
#
#
#for idx, i in enumerate(master_val):
#    if any(i != master_val_old[idx]) == True:
#        print("It is true")
#    if i.equals(master_val_old[idx]):
#        print("It is not true")
#    if i.columns.equals(master_val_old[idx].columns):
#        print("heyo")
#    print(master_val_old[idx].columns, "\n", i.columns)

# %%
columns_mapped = pd.read_excel('./Mapping_Meta_Py.xlsx', sheet_name=None)
edm_columns_mapped = pd.read_excel('./Mapping_Meta_Edm.xlsx', sheet_name=None)

# %%
class Sheet():
## name: Name des Reiters
## head: Indikator, wo im df Tabellenüberschriften zu finden sind (0 = Inhalte Zeile 1, 1 = Inhalte Zeile 2, x = Index unverändert)
## df: DataFrame pro Sheet
## tdf: Kopie von df, mit über head definierter Indexanpassung
## tdf_empty_transposed: DataFrame, der nur aus Überschriften (ohne Spaltenachsennamen) besteht, zur Konvertierung nach Excel, inklusive Transponierung
    def __init__(self, name, head, df, graph):
        self.name = name
        self.head = head
        self.df = df
        self.graph = graph
        self.tdf = df.copy()
        self.column_names = None
        self.tdf_empty_transposed = None
        
        if self.head != "x":
            self.tdf.columns = self.tdf.iloc[self.head]
            self.tdf.columns.name = None
        else:
            pass
        if isinstance(self.tdf, pd.DataFrame):
            self.column_names = self.tdf.columns.tolist()
            self.tdf_empty_transposed = self.tdf[0:0].transpose(copy=True)

# %%
## Zur Erzeungung von Sheet Instanzen mit Name und Spaltenkopfreferenz als Liste und mit dict Referenz
## column_headers: Liste von 'echten' Spaltenüberschriften, 0, 1, für erste, zweite Zeile, x=Standard
## col_ref dict um nicht mit Zahlen, sondern Namen zu arbeiten
## sheet_dict manuell, falls Verschiebungen in Tabelle passieren
old_sheet_list = []
sheet_list = []
col_ref = {}
sheet_dict = {"Produktionen":0,
             "Ereignisse":0,
             "Objekte VIDEOS":0,
             "Objekte TEXT":0,
             "Objekte BILD":0,
             "Objekte AUDIO":0,
             "||_Personen":1,
             "||_Gruppen_Ensembles":"x",
             "||_Veranstaltungsort":"x",
             "||_Städte":"x",
             "||_Länder":"x",
             "Sammlungen":"x",
             "Serie":"x"}

for idx, i in enumerate(sheet_dict.keys()):
    old_sheet_list.append(Sheet(name = i, head = sheet_dict[i], df = nvt_master_old[i], graph = graph_list[idx]))
    sheet_list.append(Sheet(name = i, head = sheet_dict[i], df = nvt_master[i], graph = graph_list[idx]))
    col_ref[i] = sheet_list[idx]

# %%
#writer_trigger = False
#for idx, sheet in enumerate(sheet_list):
#    new_sheet = sheet.tdf
#    old_sheet = old_sheet_list[idx].tdf
#    if new_sheet.columns.equals(old_sheet.columns) == True:
#        print("true")
#        pass
#    else:
#        print("it is equals yes it does")
#        print(new_sheet.columns)
#        print(old_sheet.columns)
#        writer_trigger = True
#        break
## könnte alle abweichenden columns in neuer file gelb markieren

# %%
class Mapping():
    
    def __init__(self, sheet, df, title, rdfp, original, subj, objclass, objtype, merge, titledict, sheetid):
        self.sheet = sheet
        self.df = df
        self.title = title
        self.rdfp = rdfp
        self.original = original
        self.subj = subj
        self.objclass = objclass
        self.objtype = objtype
        self.merge = merge
        self.titledict = titledict
        self.sheetid = sheetid

# %%
edm_mapping_list = mapping_to_dict(edm_columns_mapped)
mapping_list = mapping_to_dict(columns_mapped)

# %%
all(elem in list(mapping_list[0].title)  for elem in sheet_list[0].column_names) ## gegencheck, ist mapping_meta_py ok?
# Out:
# True

# %%
mapping_list[0].titledict
# Out:
# {'Identifier / geeinigter Name': ['ID', nan, nan, nan, nan, 'Reference', nan],
#  'Produktionsname / Titel': [nan,
#   nan,
#   nan,
#   nan,
#   'Title + preferred label',
#   'Literal',
#   nan],
#  'Beschreibung': ['description1', nan, nan, nan, nan, nan, nan],
#  'Quelle (Beschreibung)': ['description2', nan, nan, nan, nan, nan, nan],
#  'Verwendete Texte': ['texts1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'theoretisch als InformationObject möglich'],
#  'Autor(en) der Texte': ['texts2',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   '(dann mit Agent)'],
#  'Produktionstyp': [nan, nan, nan, nan, 'Has Type', 'Reference', nan],
#  'referenziert Produktion': [nan,
#   nan,
#   nan,
#   nan,
#   'contains reference to',
#   'Reference',
#   nan],
#  'beruht auf Produktion': [nan,
#   nan,
#   nan,
#   nan,
#   'is influenced by',
#   'Reference',
#   nan],
#  'Wiederaufnahme von': [nan,
#   nan,
#   nan,
#   nan,
#   'is restaged version of',
#   'Reference',
#   nan],
#  'Erstaufführungsversion von': [nan,
#   nan,
#   nan,
#   nan,
#   'is first performance version of',
#   'Reference',
#   nan],
#  'Nachfolger von': [nan, nan, nan, nan, 'has  predecessor', 'Reference', nan],
#  'Weitere Typen': [nan, nan, nan, nan, nan, nan, nan],
#  'Beteiligte Gruppen / Compagnies': [nan,
#   nan,
#   nan,
#   nan,
#   'Contributor',
#   'Reference',
#   nan],
#  'Konzept': [nan, nan, nan, nan, 'has concept originator', 'Reference', nan],
#  'Textbearbeitung': [nan, nan, nan, nan, 'has adaptor', 'Reference', nan],
#  'Übersetzung': [nan, nan, nan, nan, 'has translator', 'Reference', nan],
#  'Regie': [nan, nan, nan, nan, 'has director', 'Reference', nan],
#  'Sprecher*in': [nan, nan, nan, nan, 'has speaker', 'Reference', nan],
#  'Choreographie': [nan, nan, nan, nan, 'has choreographer', 'Reference', nan],
#  'Dramaturgie': [nan, nan, nan, nan, 'has dramaturge', 'Reference', nan],
#  'Bühnenbild': [nan, nan, nan, nan, 'has set designer', 'Reference', nan],
#  'Kostümdesgin': [nan,
#   nan,
#   nan,
#   nan,
#   'has costume designer',
#   'Reference',
#   nan],
#  'Figurenbau': [nan, nan, nan, nan, 'has puppet designer', 'Reference', nan],
#  'Maskenbau': [nan, nan, nan, nan, 'has mask designer', 'Reference', nan],
#  'Lichtdesign': [nan, nan, nan, nan, 'has light designer', 'Reference', nan],
#  'Videodesign': [nan, nan, nan, nan, 'has set designer', 'Reference', nan],
#  'Schauspieler': [nan, nan, nan, nan, 'has actor', 'Reference', nan],
#  'Tänzer': [nan, nan, nan, nan, 'has dancer', 'Reference', nan],
#  'Darsteller allgem.': [nan, nan, nan, nan, 'has performer', 'Reference', nan],
#  'Musiker': [nan, nan, nan, nan, 'has musician', 'Reference', nan],
#  'Komposition': [nan, nan, nan, nan, 'has composer', 'Reference', nan],
#  'Musik (für GEMA)': [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'mtt_a = MTT administrative'],
#  'Weitere Mitwirkende': [nan, nan, nan, nan, 'Contributor', 'Reference', nan],
#  'Premierendatum': [nan,
#   nan,
#   nan,
#   nan,
#   'has first performance date',
#   'Literal',
#   nan],
#  'Dernierendatum': [nan,
#   nan,
#   nan,
#   nan,
#   'has last performance date',
#   'Literal',
#   nan],
#  'Spielzeit / Laufzeit Start': ['season1',
#   'Spielzeit',
#   nan,
#   nan,
#   'begins at time',
#   'Literal',
#   nan],
#  'Spielzeit / Laufzeit Ende': ['season2',
#   'Spielzeit',
#   nan,
#   nan,
#   'ends at time',
#   'Literal',
#   nan],
#  'Veranstaltungsort': [nan,
#   nan,
#   nan,
#   nan,
#   'has related place',
#   'Reference',
#   nan],
#  'Stadt': [nan, nan, nan, nan, 'has related place', 'Reference', nan],
#  'Land': [nan, nan, nan, nan, 'has related place', 'Reference', nan],
#  'Spielzeit': ['season', nan, nan, nan, 'has season', 'Reference', nan],
#  'Beschreibung_Quelle': ['description',
#   nan,
#   nan,
#   nan,
#   'Description',
#   'Literal',
#   nan],
#  'Texte_Autoren': ['texts', nan, nan, nan, 'Source', 'Literal', nan]}

# %%
#bei Produktionen sollte am Ende nach 'XX_' gesucht werden, nicht nach PR, und der Typ bei Produktionen wird dann durch die Typenspalte bestimmt
tdf = col_ref["Produktionen"].tdf
tdf = (tdf[tdf['Identifier / geeinigter Name'].str.contains('PR', na=False)] ## drops all rows that don't start with 'PR' or are NaN
          .drop(tdf[tdf['Identifier / geeinigter Name'].str.contains('PR_Internationaler_Workshop_zur_Biomechanik_GITIS Moskau_Januar_1993', na=False)].index)
       )
col_ref["Produktionen"].tdf = tdf

tdf = col_ref["Ereignisse"].tdf
tdf = (tdf[tdf['Identifier / geeinigter Name'].str.contains('EV', na=False)] ## drops all rows that don't start with 'PR' or are NaN
          .drop(tdf[tdf['Identifier / geeinigter Name'].str.contains('EV_Internationaler_Workshop_zur_Biomechanik_GITIS Moskau_Januar_1993_001', na=False)].index) ## drops example line
      )
col_ref["Ereignisse"].tdf = tdf

tdf = col_ref["Objekte VIDEOS"].tdf
tdf = tdf[tdf['Projekt ID'].str.contains('vid', na=False)]
col_ref["Objekte VIDEOS"].tdf = tdf

tdf = col_ref["Objekte TEXT"].tdf
tdf = tdf[tdf['Projekt ID'].str.contains('txt', na=False)]
col_ref["Objekte TEXT"].tdf = tdf

tdf = col_ref["Objekte BILD"].tdf
tdf = tdf[tdf['Projekt ID'].str.contains('img', na=False)]
col_ref["Objekte BILD"].tdf = tdf

tdf = col_ref["Objekte AUDIO"].tdf
tdf = tdf[tdf['Projekt ID'].str.contains('aud', na=False)]
col_ref["Objekte AUDIO"].tdf = tdf

tdf = col_ref["||_Personen"].tdf
tdf = tdf.drop(tdf[tdf['Identifier / geeinigte Schreibweise'].str.contains('Vorname Vatersname,Nachname', na=False)].index)
col_ref["||_Personen"].tdf = tdf

tdf = col_ref["||_Gruppen_Ensembles"].tdf
tdf = tdf[tdf['Gruppe Identifier / geeinigte Schreibweise'].str.contains('G_', na=False)]
col_ref["||_Gruppen_Ensembles"].tdf = tdf

tdf = col_ref["||_Veranstaltungsort"].tdf
tdf = tdf[tdf['PROJEKT'].str.contains('LOC_', na=False)]
col_ref["||_Veranstaltungsort"].tdf = tdf
       
tdf = col_ref["Sammlungen"].tdf
tdf = (tdf[tdf['PROJEKT'].str.contains('COL_', na=False)]
          .drop(tdf[tdf['PROJEKT'].str.contains('COL_Identifier', na=False)].index)
      )
col_ref["Sammlungen"].tdf = tdf

tdf = col_ref["Serie"].tdf      
tdf = (tdf[tdf['PROJEKT'].str.contains('SRS_', na=False)]
           .drop(tdf[tdf['PROJEKT'].str.contains('SRS_Identifier', na=False)].index)
       )
col_ref["Serie"].tdf = tdf

for sdx, sheet in enumerate(col_ref):
      col_ref[sheet].tdf = sort_reindex(col_ref[sheet].tdf, index=mapping_list[sdx].sheetid) ## das könnte auch für alle auf einmal passieren for tdf sort_reindex

# %%
# für alle Spalten in allen Sheets wird merge_columns angewandt
# mapping_list[sdx].title = alle Spalten
# mapping_list[sdx].merge[0] = ID des Sheets, 0, weil Dict seltsam in Liste
# mapping_list[sdx].original[cdx] = für die Keywords in merge_columns, könnte man vllt auch mit merge[0] machen

for sdx, sheet in enumerate(sheet_list):
    for cdx, column in enumerate(mapping_list[sdx].title):
        merge_columns(sheet, mapping_list[sdx].merge[0], mapping_list[sdx].original[cdx]) # für die zusammengesetzten Spalten für z.B. Spielzeit Beschreibung Texte

# %%
len(sheet_list[10].tdf["geonames URI"].value_counts()) == 0
# Out:
# True

# %%
# Schleife muss getrennt von der oberen laufen, weil in der unteren Listen erzeugt werden, die nicht mehr für die oberen verwendbar sind
# mapping_list[sdx].title = alle Spalten
# mapping_list[sdx].titledict[column][5] verbindet Spalte mit Keyword "Reference"
# splitreplace wandelt alle Reference Zeilen zu Listen mit Referenzen um
# len(sheet_list[sdx].tdf[column].value_counts()) > 0 prüft die 
for sdx, sheet in enumerate(sheet_list):
    for cdx, column in enumerate(mapping_list[sdx].title):
        reference = mapping_list[sdx].titledict[column][5]
        if reference == "Reference" and len(sheet_list[sdx].tdf[column].value_counts()) > 0:
            sheet_list[sdx].tdf[column] = splitreplace(sheet_list[sdx].tdf[column])

# %%
list(sheet_list[0].tdf.columns) == list(mapping_list[0].title)
# Out:
# True

# %%
sheet_list[0].tdf
# Out:
#                           Identifier / geeinigter Name  \
# 0                       [pr_12_traeume_des_dr_fridkin]
# 1                                          [pr_7_soli]
# 2                     [pr_aber_macht_keine_dummheiten]
# 3                                         [pr_amapola]
# 4                                       [pr_ameriques]
# 5                            [pr_aufstand_der_traeume]
# 6                                   [pr_august_august]
# 7                                    [pr_avat_theater]
# 8                                        [pr_babyzarr]
# 9                                       [pr_baustelle]
# 10                              [pr_beet_naar_de_maan]
# 11                     [pr_berliner_ballonfieber_1803]
# 12                       [pr_bilder_einer_ausstellung]
# 13                                       [pr_blaubart]
# 14                         [pr_bremer_stadtmusikanten]
# 15                                     [pr_cafe_fatal]
# 16                                     [pr_caoutchouc]
# 17                                    [pr_capitombola]
# 18                            [pr_carambolage_d_amour]
# 19                                   [pr_clean_spleen]
# 20                                     [pr_clownerien]
# 21                                     [pr_clownonade]
# 22                                [pr_clowns_non_stop]
# 23                                   [pr_clownsfamily]
# 24                                      [pr_confusion]
# 25                                    [pr_crazy_music]
# 26                               [pr_danse_et_musique]
# 27                               [pr_das_narrenschiff]
# 28                              [pr_der_erste_schritt]
# 29                             [pr_der_grosse_nepomuk]
# ..                                                 ...
# 92                                      [pr_stadtgang]
# 93                                     [pr_striptease]
# 94                                         [pr_studie]
# 95                                 [pr_sucking_stones]
# 96   [pr_sunny_side_up_oder_ein_stueck_von_der_leiter]
# 97                                         [pr_svatba]
# 98                                         [pr_szenen]
# 99                    [pr_tagebuch_eines_wahnsinnigen]
# 100                                    [pr_tanzschule]
# 101                           [pr_the_cry_of_the_body]
# 102                               [pr_the_faust_quest]
# 103                                   [pr_tief_in_uns]
# 104                                     [pr_traumwelt]
# 105                         [pr_ueber_den_berg_kommen]
# 106                             [pr_ullyssee_ullyssee]
# 107                   [pr_unternehmen_strassentheater]
# 108                                     [pr_valentino]
# 109                               [pr_verruecktwaerts]
# 110                [pr_viele_dinge_sind_in_einem_ding]
# 111                                    [pr_vogelmogel]
# 112             [pr_von_kalaf_und_prinzessin_turandot]
# 113             [pr_wer_hat_angst_vorm_schwarzen_mann]
# 114                             [pr_werkstattprogramm]
# 115                                    [pr_wir_wohner]
# 116                                 [pr_wir_wohner_ii]
# 117                                [pr_wir_wohner_iii]
# 118           [pr_zehn_tage_die_die_welt_veraenderten]
# 119                       [pr_zwischen_tuer_und_angel]
# 120                                  [pr_beauti_fools]
# 121                    [pr_und_alle_haben_ein_gesicht]
#
#                                                                                                     Produktionsname / Titel  \
# 0                                                                                                 12 Träume des Dr. Fridkin
# 1                                                                                                                    7 Soli
# 2                                                                                              Aber, macht keine Dummheiten
# 3                                                                                                                   Amapola
# 4                                                                                                                 Amériques
# 5                                                                                                       Aufstand der Träume
# 6                                                                                                            August, August
# 7                                                                                                             Avant-Theater
# 8                                                                                                                  BABYZARR
# 9                                                                                                                 Baustelle
# 10                                                                                                        Beet naar de maan
# 11   Berliner Ballonfieber 1803 oder Verfolgung und Verklärung des entsprungenen Sträfling Jakob Daluschke, genannt Knetsch
# 12                                                                                                 Bilder einer Ausstellung
# 13                                                                                  Blaubart. Fünf Burlesken in einem Spiel
# 14                                                                                                   Bremer Stadtmusikanten
# 15                                                                                                Café Fatal. Eine Groteske
# 16                                                                                                               Caoutchouc
# 17                                                                                                              Capitombola
# 18                                                                                                     Caramboulage d'Amour
# 19                                                                                Clean Spleen. Ein galaktisches Intermezzo
# 20                                                                                                               Clownerien
# 21                                                                                                               Clownonade
# 22                                                                                                          Clowns non stop
# 23                                                                                                             Clownsfamily
# 24                                                                                                                Confusion
# 25                                                                                                              Crazy Music
# 26                                                                                           Danse et Musique Contemporaine
# 27                                                                                                         Das Narrenschiff
# 28                                                                                                        Der erste Schritt
# 29                                                                                                        Der große Nepomuk
# ..                                                                                                                      ...
# 92                                                                                                                Stadtgang
# 93                                                                                                               Striptease
# 94                                                                                                                      NaN
# 95                                                                                                           Sucking Stones
# 96                                                                              Sunny Side Up oder ein Stück von der Leiter
# 97                                                                                                    Die Hochzeit / Svatba
# 98                                                                                                                   Szenen
# 99                                                                                              Tagebuch eines Wahnsinnigen
# 100                                                                                                              Tanzschule
# 101                                                                                                     The Cry of the Body
# 102                                                                                       The Faust Quest / Luzifers Lament
# 103                                                                      Tief in uns. Seelisches Krankenblatt zweier Clowns
# 104                                                                                                    Traumwelt / Svět Snů
# 105                                                                                                    Über den Berg kommen
# 106                                                                                                      Ullysee, Ullyssee!
# 107                                                                                              Unternehmen Straßentheater
# 108                                                                                                               Valentino
# 109                                                                                 Verrücktwärts. Zwei Grotesken zur Nacht
# 110                                                                                          Viele Dinge sind in einem Ding
# 111                                                                                                              Vogelmogel
# 112                                                                                       Von Kalaf und Prinzessin Turandot
# 113                                                                                      Wer hat Angst vor'm schwarzen Mann
# 114                                                                                                       Werkstattprogramm
# 115                                                                                                              Wir Wohner
# 116                                                                                                           Wir Wohner II
# 117                                                                                                          Wir Wohner III
# 118                                                                                     Zehn Tage, die die Welt veränderten
# 119                                                                                                  Zwischen Tür und Angel
# 120                                                                                                             beautiFOOLS
# 121                                                                                              und alle haben ein Gesicht
#
#                                                                                                                                         Beschreibung  \
# 0    Produktion des Mime-Theater "Version" aus Tscheljabinsk, die eine "phantastische, surreale Welt" erschafft, in der kopflose Körper in "wortl...
# 1                                                                                                                                                NaN
# 2                                                                                                                                                NaN
# 3                                                                                                                                                NaN
# 4    Eine Inszenierung ohne Text nach einer Komposition von Edgar Varèse. Ein Bewegungstheaterstück für acht Spieler zum Thema Erschließung der W...
# 5                                                                                                                                         Mimodrama.
# 6                                                                                                                                                NaN
# 7    Theaterstück in drei Teilen "Das Netz oder der Alltag der Fischer", "Die Hütte oder die Suche nach Gold", "Die Reise oder die beängstigende ...
# 8                                                                                                                                                NaN
# 9    Klamauk, Akrobatik und Artistik im Baugerüst. Die sechs Bauarbeiter in der halbfertigen Überbauung "Mieterglück", die mit Hammer, Sichel, Sä...
# 10                                                                          Eine Bewegungstheaterproduktionn, die mit Geschlechtsidentitäten spielt.
# 11                                                                      Weitere Mitwirkende: Kinder des Ensembles und Mitglieder des Amateurstudios.
# 12   Pantomimensolo; als Grundlage dafür dient die in elektronische Musik umgesetzte Orchesterfassung (Ravel) von Mussorgskis Klavierzyklus gleic...
# 13                                                                                                                                               NaN
# 14                                                                                                                                               NaN
# 15                                                                                                                                               NaN
# 16   In dieser Produktion wir die Bühne durch Hunderte von Gummibändern in ein bewegtes Meer verwandelt. Im Flechtwerk der beweglichen Mauer wird...
# 17                                                                                           Eine Farce von Liebe und Verfall für drei Musikrobaten.
# 18                                                                                                                                               NaN
# 19    In der neuesten Produktion von Finke / Faltz geraten Menschen auf einer galaktischen Hochzeitsreise in außergewöhnliche Situationen. Fragen...
# 20                                                                          Lustige und ernste Spiele von sechs Clowns. Für Kinder ab sieben Jahren.
# 21                                                                                                                                               NaN
# 22   In ihren ausgefeilten Slapsticknummern verbindet Salto Vitale Clownerie mit Pantomime und absurdem Theater, spielt souverän mit den klassisc...
# 23                                                                                                                                               NaN
# 24   "Confusion" beginnt mit Szenen aus dem Alltag. Aus dem alltäglichen Gutentagsagen entstehen witzige, amüsierende und verwirrende Szene, Allt...
# 25                                                                                                                                               NaN
# 26   Aus der französichen Theatergruppe Mimobile heraus gründete Jörn Gehlker zusammen mit Muriel Masson und Hans van Zyp eine eingene Truppe. "D...
# 27   Die aus Brettern gezimmerte Bühne, mit Seilen zusammengebundene Masten, an denen bemalte Planen gehißt werden - das ist jenes Floß, welches ...
# 28                                                                                                                                               NaN
# 29                                                                                                                                               NaN
# ..                                                                                                                                               ...
# 92                                                                                                                                               NaN
# 93   Eine Inszenierung mit Ioan Tomas Theater im Würfel - einer kubusförmigen, für die Inszenierung von Gogols "Tagebuch eines Whansinnigen" entw...
# 94                                                                                                                                               NaN
# 95   Absurdes Objekt- und Bewegungstheater von und mit Paul Clark nach Motiven des Textes "Molloy stirbt" von Samuel Beckett und eine Figur von C...
# 96   Avantgardistische Solo-Inszenierung und Co-Produktion Compagnie Patrice Bigel/La Rumeur, Paris und studio gold egg, Wien. UA: 1988-05-28. Fü...
# 97                                                                                                                                               NaN
# 98                                                                                                                                               NaN
# 99   Für seine Inszenierung von Gogols Text entwarf Ioan Thoma eine kubusförmige Stahlkonstruktion mit gespannten Seilen, in die sich der Protago...
# 100                                                                                                                                              NaN
# 101  "Le Cri du Corps" wurde 1972 entwickelt und gehört zum Repertoire, mit dem der argentinische Regisseur und Darsteller Benito Gutmacher von 1...
# 102                                                                                                                                              NaN
# 103  Programm von Constanze Debus und Lutz Jope des Pantomimestudio Dresden Salto Vitale, Ablauf:\nVorspiel\nBergsteiger I\nHund und Herrchen\nBe...
# 104                                                                                                                                              NaN
# 105                                                                                          Ein poetisches Drama über die Dichterin Onono Komatshi.
# 106                                                                                                                                              NaN
# 107                                                                                                                                              NaN
# 108  Das Stück bearbeitet die Lebensgeschichte des Stummfilmstars Rodolfo Valentino. Die Titelfigur dieses stark mimisch geprägten Spektakels ble...
# 109                                                                                                                                              NaN
# 110  Eberhard Kube - Gründer und langjähriger künstlerischer Leiter des Theaters - verwendete für die Realisierung der brechtschen Vorlage ("Die ...
# 111         Komisch-satirisches Pantomimenprogramm, in dem Alltagsituationen unter Verwendung clownesker Elemente dargestellt und verfremdet werden.
# 112                                                                                                                                              NaN
# 113  Die verwendeten Texte und Lieder stammen u.a. "Des Knaben Wunderhorn" (Meersburg 1928), "Deutsche Volkslieder des Mittelalters (Berlin, 1922...
# 114  Mit dem Werkstattprogramm sollte die Breite der pantomimischen Arbeit des Ensembles dokumentiert werden, ohne notwendigerweise eine geschlos...
# 115  Umfangreiches Programm (Szenenfolge; u. a. "Die Hofsänger" von Helga und Clemens de Wroblewsky) des Pantomimentheater vom Prenzlauer Berg, d...
# 116  Fortführung des "Wohner"-Programms des Pantomimentheater vom Prenzlauer Berg. Es fand ebenfalls im Kreiskulturhaus Prater statt. In den Paus...
# 117                                                                                                                                              NaN
# 118                                                    Inszenierung für ein Programm zum 60. Jahrestag der Oktoberrevolution im Palast der Republik.
# 119                                                                                                                                              NaN
# 120  "beautiFOOLS" ist die meistgespielte, erfolgreichste Tanztheater-Choreographie der Schweiz der letzten Jahre [Stand 1990]. "beautiFOOLS" ist...
# 121                                                                Abendprogramm des Studio 61 (Premiere: 1967) unter der Leitung von Eberhard Kube.
#
#                                                                                                                                Quelle (Beschreibung)  \
# 0                                                                                                TN; Programmheft Woche des Gestischen Theaters 1990
# 1                                                                                                                                                NaN
# 2                                                                                                                                                NaN
# 3                                                                                                                                                NaN
# 4                                                                                                                                                NaN
# 5                                                                                                                                                NaN
# 6                                                                                                                                                NaN
# 7                                                                                                                                    CW; txt-007-001
# 8                                                                                                                                                NaN
# 9                                                                                                    Programmheft Woche des Gestischen Theaters 1990
# 10                                                                                                                                                TN
# 11                                                                                                                                               NaN
# 12                                                                                               TN; Programmheft Woche des Gestischen Theaters 1988
# 13                                                                                                                                               NaN
# 14                                                                                                                                               NaN
# 15                                                                                                                                               NaN
# 16                                                                                               TN; Programmheft Woche des Gestischen Theaters 1988
# 17                                                                                                                                   CW; txt-081-003
# 18                                                                                                                                               NaN
# 19                                                                                                   Programmheft Woche des Gestischen Theaters 1990
# 20                                                                                                                                   CW; txt-008-001
# 21                                                                                                                                               NaN
# 22                                                                                                   Programmheft Woche des Gestischen Theaters 1990
# 23                                                                                                                                               NaN
# 24                                                                                                   Programmheft Woche des Gestischen Theaters 1990
# 25                                                                                                                                               NaN
# 26                                                                                                    http://archiv.mimecentrum.de/videos/MCB-TV-275
# 27                                                                                                   Programmheft Woche des Gestischen Theaters 1990
# 28                                                                                                                                               NaN
# 29                                                                                                                                               NaN
# ..                                                                                                                                               ...
# 92                                                                                                                                               NaN
# 93                                                                                                                                               NaN
# 94                                                                                                                                               NaN
# 95                                                TN; Programmheft Woche des Gestischen Theaters 1988;http://archiv.mimecentrum.de/videos/MCB-TV-151
# 96                                                                                                                                   CW; txt-007-001
# 97                                                                                                                                                TN
# 98                                                                                                                                               NaN
# 99                                                                                                                                               NaN
# 100                                                                                                                                              NaN
# 101                                                                                            http://www.theater-kurse.de/Le%20Cri%20du%20Corps.htm
# 102                                                                                                                                              NaN
# 103                                                                                                                                               TN
# 104                                                                                                                                              NaN
# 105                                                                                              TN; Programmheft Woche des Gestischen Theaters 1988
# 106                                                                                                                                              NaN
# 107                                                                                                                                              NaN
# 108                                                TN;http://archiv.mimecentrum.de/videos/MCB-TV-734;Programmheft Woche des Gestischen Theaters 1990
# 109                                                                                                                                              NaN
# 110                                                                                               TN;http://archiv.mimecentrum.de/videos/MCB-SV-1415
# 111                                                                                              TN; Programmheft Woche des Gestischen Theaters 1988
# 112                                                                                                                                              NaN
# 113                                                                                                                              CW; txt-079-001-001
# 114  TN; Debus, Constance: Geschichte des Pantomimentheaters vom Prenzlauer Begr. Diplomarbeit. Berlin, Hochschule für Schauspielkunst "Ernst Bus...
# 115                                                                                                                                              NaN
# 116                                                                                                                                              NaN
# 117                                                                                                                                              NaN
# 118                                                                                                                                      TN, txt-167
# 119                                                                                                                                              NaN
# 120                                                                                                                                              NaN
# 121                                                                                                                                      TN, txt-153
#
#                    Verwendete Texte   Autor(en) der Texte  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
# 3                               NaN  Omar Saavedra Santis
# 4                               NaN                   NaN
# 5               Aufstand der Träume        Andreas Ittner
# 6                               NaN                   NaN
# 7                               NaN                   NaN
# 8                               NaN                   NaN
# 9                               NaN                   NaN
# 10                              NaN                   NaN
# 11                              NaN                   NaN
# 12                              NaN                   NaN
# 13                              NaN                   NaN
# 14                              NaN                   NaN
# 15                              NaN                   NaN
# 16                              NaN                   NaN
# 17                              NaN                   NaN
# 18                              NaN                   NaN
# 19                              NaN                   NaN
# 20                              NaN                   NaN
# 21                              NaN                   NaN
# 22                              NaN                   NaN
# 23                              NaN                   NaN
# 24                              NaN                   NaN
# 25                              NaN                   NaN
# 26                              NaN                   NaN
# 27                              NaN                   NaN
# 28                              NaN                   NaN
# 29                              NaN                   NaN
# ..                              ...                   ...
# 92                              NaN                   NaN
# 93                       Striptease       Slawomir Mrozek
# 94                              NaN                   NaN
# 95                     Molly stirbt        Samuel Beckett
# 96                              NaN                   NaN
# 97                     Die Hochzeit        Bertolt Brecht
# 98                              NaN                   NaN
# 99      Tagebuch eines Wahnsinnigen        Nikolaij Gogol
# 100                             NaN                   NaN
# 101                             NaN                   NaN
# 102                             NaN                   NaN
# 103                             NaN                   NaN
# 104                             NaN                   NaN
# 105                             NaN                   NaN
# 106                             NaN                   NaN
# 107                             NaN                   NaN
# 108                             NaN                   NaN
# 109                             NaN                   NaN
# 110  Die Horatier und die Kuriatier        Bertolt Brecht
# 111                             NaN                   NaN
# 112                             NaN                   NaN
# 113                             NaN                   NaN
# 114                             NaN                   NaN
# 115                             NaN                   NaN
# 116                             NaN                   NaN
# 117                             NaN                   NaN
# 118      Legende vom toten Soldaten        Bertolt Brecht
# 119                             NaN                   NaN
# 120                             NaN                   NaN
# 121                             NaN                   NaN
#
#                    Produktionstyp referenziert Produktion  \
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN
# 5                             NaN                     NaN
# 6                             NaN                     NaN
# 7                             NaN                     NaN
# 8    [produktion_performing_arts]                     NaN
# 9                             NaN                     NaN
# 10                            NaN                     NaN
# 11                            NaN                     NaN
# 12                            NaN                     NaN
# 13   [produktion_performing_arts]                     NaN
# 14                            NaN                     NaN
# 15   [produktion_performing_arts]                     NaN
# 16                            NaN                     NaN
# 17                            NaN                     NaN
# 18                            NaN                     NaN
# 19                            NaN                     NaN
# 20                            NaN                     NaN
# 21                            NaN                     NaN
# 22                            NaN                     NaN
# 23                            NaN                     NaN
# 24                            NaN                     NaN
# 25                            NaN                     NaN
# 26                            NaN                     NaN
# 27                            NaN                     NaN
# 28                            NaN                     NaN
# 29                            NaN                     NaN
# ..                            ...                     ...
# 92                            NaN                     NaN
# 93                            NaN                     NaN
# 94                            NaN                     NaN
# 95                            NaN                     NaN
# 96                            NaN                     NaN
# 97                            NaN                     NaN
# 98                            NaN                     NaN
# 99                            NaN                     NaN
# 100                           NaN                     NaN
# 101                           NaN                     NaN
# 102                           NaN                     NaN
# 103                           NaN                     NaN
# 104                           NaN                     NaN
# 105                           NaN                     NaN
# 106                           NaN                     NaN
# 107                           NaN                     NaN
# 108                           NaN                     NaN
# 109                           NaN                     NaN
# 110                           NaN                     NaN
# 111                           NaN                     NaN
# 112                  [produktion]                     NaN
# 113                           NaN                     NaN
# 114                           NaN                     NaN
# 115                           NaN                     NaN
# 116                           NaN                     NaN
# 117                           NaN                     NaN
# 118                           NaN                     NaN
# 119                           NaN                     NaN
# 120                           NaN                     NaN
# 121                           NaN                     NaN
#
#     beruht auf Produktion Wiederaufnahme von  ...              Premierendatum  \
# 0                     NaN                NaN  ...                         NaN
# 1                     NaN                NaN  ...                         NaN
# 2                     NaN                NaN  ...                         NaN
# 3                     NaN                NaN  ...                         NaN
# 4                     NaN                NaN  ...         1985-04-16 00:00:00
# 5                     NaN                NaN  ...                         NaN
# 6                     NaN                NaN  ...                         NaN
# 7                     NaN                NaN  ...                         NaN
# 8                     NaN                NaN  ...                  1988-00-00
# 9                     NaN                NaN  ...                         NaN
# 10                    NaN                NaN  ...         1988-09-13 00:00:00
# 11                    NaN                NaN  ...                  1987-07-13
# 12                    NaN                NaN  ...                         NaN
# 13                    NaN                NaN  ...                  1981-11-14
# 14                    NaN                NaN  ...                         NaN
# 15                    NaN                NaN  ...                  1988-04-07
# 16                    NaN                NaN  ...                  1988-00-00
# 17                    NaN                NaN  ...                         NaN
# 18                    NaN                NaN  ...                  1986-00-00
# 19                    NaN                NaN  ...                         NaN
# 20                    NaN                NaN  ...                  1980-05-12
# 21                    NaN                NaN  ...                         NaN
# 22                    NaN                NaN  ...                         NaN
# 23                    NaN                NaN  ...                         NaN
# 24                    NaN                NaN  ...                         NaN
# 25                    NaN                NaN  ...                         NaN
# 26                    NaN                NaN  ...                         NaN
# 27                    NaN                NaN  ...                         NaN
# 28                    NaN                NaN  ...                  1961-00-00
# 29                    NaN                NaN  ...                         NaN
# ..                    ...                ...  ...                         ...
# 92                    NaN                NaN  ...                         NaN
# 93                    NaN                NaN  ...                  1988-00-00
# 94                    NaN                NaN  ...  1990-00-00 oder 1991-00-00
# 95                    NaN                NaN  ...                         NaN
# 96                    NaN                NaN  ...                         NaN
# 97                    NaN                NaN  ...         1978-03-11 00:00:00
# 98                    NaN                NaN  ...                         NaN
# 99                    NaN                NaN  ...                  1988-00-00
# 100                   NaN                NaN  ...                         NaN
# 101                   NaN                NaN  ...                         NaN
# 102                   NaN                NaN  ...         1990-07-02 00:00:00
# 103                   NaN                NaN  ...         1987-10-16 00:00:00
# 104                   NaN                NaN  ...         1981-01-13 00:00:00
# 105                   NaN                NaN  ...                         NaN
# 106                   NaN                NaN  ...                         NaN
# 107                   NaN                NaN  ...                         NaN
# 108                   NaN                NaN  ...                  1989-00-00
# 109                   NaN                NaN  ...                  1984-11-24
# 110                   NaN                NaN  ...                  1979-10-00
# 111                   NaN                NaN  ...                         NaN
# 112                   NaN                NaN  ...                  1977-10-29
# 113                   NaN                NaN  ...                  1979-10-23
# 114                   NaN                NaN  ...                  1984-00-00
# 115                   NaN                NaN  ...                  1975-00-00
# 116                   NaN                NaN  ...                  1977-00-00
# 117                   NaN                NaN  ...                  1980-00-00
# 118                   NaN                NaN  ...                  1978-00-00
# 119                   NaN                NaN  ...                  1975-12-04
# 120                   NaN                NaN  ...                         NaN
# 121                   NaN                NaN  ...                  1967-00-00
#
#     Dernierendatum Spielzeit / Laufzeit Start Spielzeit / Laufzeit Ende  \
# 0              NaN                        NaN                       NaN
# 1              NaN                        NaN                       NaN
# 2              NaN                        NaN                       NaN
# 3              NaN                        NaN                       NaN
# 4              NaN                        NaN                       NaN
# 5              NaN                        NaN                       NaN
# 6              NaN                        NaN                       NaN
# 7              NaN                        NaN                       NaN
# 8              NaN                        NaN                       NaN
# 9              NaN                        NaN                       NaN
# 10             NaN                 1988-00-00                1990-00-00
# 11             NaN        1987-07-11 00:00:00       1978-08-02 00:00:00
# 12             NaN                        NaN                       NaN
# 13             NaN                        NaN                       NaN
# 14             NaN                        NaN                       NaN
# 15             NaN                        NaN                       NaN
# 16             NaN                        NaN                       NaN
# 17             NaN                        NaN                       NaN
# 18             NaN                        NaN                       NaN
# 19             NaN                        NaN                       NaN
# 20             NaN                        NaN                       NaN
# 21             NaN                        NaN                       NaN
# 22             NaN                        NaN                       NaN
# 23             NaN                        NaN                       NaN
# 24             NaN                        NaN                       NaN
# 25             NaN                        NaN                       NaN
# 26             NaN                        NaN                       NaN
# 27             NaN                        NaN                       NaN
# 28             NaN                        NaN                       NaN
# 29             NaN                        NaN                       NaN
# ..             ...                        ...                       ...
# 92             NaN                        NaN                       NaN
# 93             NaN                        NaN                       NaN
# 94             NaN                        NaN                       NaN
# 95             NaN                        NaN                       NaN
# 96             NaN                        NaN                       NaN
# 97             NaN                        NaN                       NaN
# 98             NaN                        NaN                       NaN
# 99             NaN                        NaN                       NaN
# 100            NaN                        NaN                       NaN
# 101            NaN                        NaN                       NaN
# 102            NaN                        NaN                       NaN
# 103            NaN                        NaN                       NaN
# 104            NaN                        NaN                       NaN
# 105            NaN                        NaN                       NaN
# 106            NaN                        NaN                       NaN
# 107            NaN                        NaN                       NaN
# 108            NaN                        NaN                       NaN
# 109            NaN                        NaN                       NaN
# 110            NaN                        NaN                       NaN
# 111            NaN                        NaN                       NaN
# 112            NaN                        NaN                       NaN
# 113            NaN                        NaN                       NaN
# 114            NaN                        NaN                       NaN
# 115            NaN                        NaN                       NaN
# 116            NaN                        NaN                       NaN
# 117            NaN                        NaN                       NaN
# 118            NaN                        NaN                       NaN
# 119            NaN                        NaN                       NaN
# 120            NaN                        NaN                       NaN
# 121            NaN                        NaN                       NaN
#
#                             Veranstaltungsort            Stadt  \
# 0                                         NaN  [tscheljabinsk]
# 1                                         NaN        [zuerich]
# 2                                         NaN              NaN
# 3                                         NaN              NaN
# 4                                         NaN      [elancourt]
# ...
# 96        [oesterreich]                                               NaN
# 97   [tschechoslowakei]                                               NaN
# 98                  NaN                                               NaN
# 99                  NaN                                               NaN
# 100                 NaN                                               NaN
# 101                 NaN                                               NaN
# 102           [brd_001]                                               NaN
# 103                 NaN                                               NaN
# 104  [tschechoslowakei]                                               NaN
# 105           [brd_001]                                               NaN
# 106        [frankreich]                                               NaN
# 107                 NaN                                               NaN
# 108   [grossbritannien]                                               NaN
# 109               [ddr]                                               NaN
# 110               [ddr]                                               NaN
# 111                 NaN                                               NaN
# 112               [ddr]                                               NaN
# 113               [ddr]                                               NaN
# 114               [ddr]                                               NaN
# 115               [ddr]                                               NaN
# 116               [ddr]                                               NaN
# 117               [ddr]                                               NaN
# 118               [ddr]                                               NaN
# 119               [ddr]                                               NaN
# 120           [schweiz]                                               NaN
# 121                 NaN                                               NaN
#
#                                                                                                                                  Beschreibung_Quelle  \
# 0    Produktion des Mime-Theater "Version" aus Tscheljabinsk, die eine "phantastische, surreale Welt" erschafft, in der kopflose Körper in "wortl...
# 1                                                                                                                                                NaN
# 2                                                                                                                                                NaN
# 3                                                                                                                                                NaN
# 4    Eine Inszenierung ohne Text nach einer Komposition von Edgar Varèse. Ein Bewegungstheaterstück für acht Spieler zum Thema Erschließung der W...
# 5                                                                                                                                         Mimodrama.
# 6                                                                                                                                                NaN
# 7    Theaterstück in drei Teilen "Das Netz oder der Alltag der Fischer", "Die Hütte oder die Suche nach Gold", "Die Reise oder die beängstigende ...
# 8                                                                                                                                                NaN
# 9    Klamauk, Akrobatik und Artistik im Baugerüst. Die sechs Bauarbeiter in der halbfertigen Überbauung "Mieterglück", die mit Hammer, Sichel, Sä...
# 10                                                               Eine Bewegungstheaterproduktionn, die mit Geschlechtsidentitäten spielt. Quelle: TN
# 11                                                                      Weitere Mitwirkende: Kinder des Ensembles und Mitglieder des Amateurstudios.
# 12   Pantomimensolo; als Grundlage dafür dient die in elektronische Musik umgesetzte Orchesterfassung (Ravel) von Mussorgskis Klavierzyklus gleic...
# 13                                                                                                                                               NaN
# 14                                                                                                                                               NaN
# 15                                                                                                                                               NaN
# 16   In dieser Produktion wir die Bühne durch Hunderte von Gummibändern in ein bewegtes Meer verwandelt. Im Flechtwerk der beweglichen Mauer wird...
# 17                                                                   Eine Farce von Liebe und Verfall für drei Musikrobaten. Quelle: CW; txt-081-003
# 18                                                                                                                                               NaN
# 19    In der neuesten Produktion von Finke / Faltz geraten Menschen auf einer galaktischen Hochzeitsreise in außergewöhnliche Situationen. Fragen...
# 20                                                  Lustige und ernste Spiele von sechs Clowns. Für Kinder ab sieben Jahren. Quelle: CW; txt-008-001
# 21                                                                                                                                               NaN
# 22   In ihren ausgefeilten Slapsticknummern verbindet Salto Vitale Clownerie mit Pantomime und absurdem Theater, spielt souverän mit den klassisc...
# 23                                                                                                                                               NaN
# 24   "Confusion" beginnt mit Szenen aus dem Alltag. Aus dem alltäglichen Gutentagsagen entstehen witzige, amüsierende und verwirrende Szene, Allt...
# 25                                                                                                                                               NaN
# 26   Aus der französichen Theatergruppe Mimobile heraus gründete Jörn Gehlker zusammen mit Muriel Masson und Hans van Zyp eine eingene Truppe. "D...
# 27   Die aus Brettern gezimmerte Bühne, mit Seilen zusammengebundene Masten, an denen bemalte Planen gehißt werden - das ist jenes Floß, welches ...
# 28                                                                                                                                               NaN
# 29                                                                                                                                               NaN
# ..                                                                                                                                               ...
# 92                                                                                                                                               NaN
# 93   Eine Inszenierung mit Ioan Tomas Theater im Würfel - einer kubusförmigen, für die Inszenierung von Gogols "Tagebuch eines Whansinnigen" entw...
# 94                                                                                                                                               NaN
# 95   Absurdes Objekt- und Bewegungstheater von und mit Paul Clark nach Motiven des Textes "Molloy stirbt" von Samuel Beckett und eine Figur von C...
# 96   Avantgardistische Solo-Inszenierung und Co-Produktion Compagnie Patrice Bigel/La Rumeur, Paris und studio gold egg, Wien. UA: 1988-05-28. Fü...
# 97                                                                                                                                        Quelle: TN
# 98                                                                                                                                               NaN
# 99   Für seine Inszenierung von Gogols Text entwarf Ioan Thoma eine kubusförmige Stahlkonstruktion mit gespannten Seilen, in die sich der Protago...
# 100                                                                                                                                              NaN
# 101  "Le Cri du Corps" wurde 1972 entwickelt und gehört zum Repertoire, mit dem der argentinische Regisseur und Darsteller Benito Gutmacher von 1...
# 102                                                                                                                                              NaN
# 103  Programm von Constanze Debus und Lutz Jope des Pantomimestudio Dresden Salto Vitale, Ablauf:\nVorspiel\nBergsteiger I\nHund und Herrchen\nBe...
# 104                                                                                                                                              NaN
# 105                              Ein poetisches Drama über die Dichterin Onono Komatshi. Quelle: TN; Programmheft Woche des Gestischen Theaters 1988
# 106                                                                                                                                              NaN
# 107                                                                                                                                              NaN
# 108  Das Stück bearbeitet die Lebensgeschichte des Stummfilmstars Rodolfo Valentino. Die Titelfigur dieses stark mimisch geprägten Spektakels ble...
# 109                                                                                                                                              NaN
# 110  Eberhard Kube - Gründer und langjähriger künstlerischer Leiter des Theaters - verwendete für die Realisierung der brechtschen Vorlage ("Die ...
# 111  Komisch-satirisches Pantomimenprogramm, in dem Alltagsituationen unter Verwendung clownesker Elemente dargestellt und verfremdet werden. Que...
# 112                                                                                                                                              NaN
# 113  Die verwendeten Texte und Lieder stammen u.a. "Des Knaben Wunderhorn" (Meersburg 1928), "Deutsche Volkslieder des Mittelalters (Berlin, 1922...
# 114  Mit dem Werkstattprogramm sollte die Breite der pantomimischen Arbeit des Ensembles dokumentiert werden, ohne notwendigerweise eine geschlos...
# 115  Umfangreiches Programm (Szenenfolge; u. a. "Die Hofsänger" von Helga und Clemens de Wroblewsky) des Pantomimentheater vom Prenzlauer Berg, d...
# 116  Fortführung des "Wohner"-Programms des Pantomimentheater vom Prenzlauer Berg. Es fand ebenfalls im Kreiskulturhaus Prater statt. In den Paus...
# 117                                                                                                                                              NaN
# 118                                Inszenierung für ein Programm zum 60. Jahrestag der Oktoberrevolution im Palast der Republik. Quelle: TN, txt-167
# 119                                                                                                                                              NaN
# 120  "beautiFOOLS" ist die meistgespielte, erfolgreichste Tanztheater-Choreographie der Schweiz der letzten Jahre [Stand 1990]. "beautiFOOLS" ist...
# 121                                            Abendprogramm des Studio 61 (Premiere: 1967) unter der Leitung von Eberhard Kube. Quelle: TN, txt-153
#
#                                                          Texte_Autoren
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                      Autor(en): Omar Saavedra Santis
# 4                                                                  NaN
# 5               Text(e): Aufstand der Träume Autor(en): Andreas Ittner
# 6                                                                  NaN
# 7                                                                  NaN
# 8                                                                  NaN
# 9                                                                  NaN
# 10                                                                 NaN
# 11                                                                 NaN
# 12                                                                 NaN
# 13                                                                 NaN
# 14                                                                 NaN
# 15                                                                 NaN
# 16                                                                 NaN
# 17                                                                 NaN
# 18                                                                 NaN
# 19                                                                 NaN
# 20                                                                 NaN
# 21                                                                 NaN
# 22                                                                 NaN
# 23                                                                 NaN
# 24                                                                 NaN
# 25                                                                 NaN
# 26                                                                 NaN
# 27                                                                 NaN
# 28                                                                 NaN
# 29                                                                 NaN
# ..                                                                 ...
# 92                                                                 NaN
# 93                      Text(e): Striptease Autor(en): Slawomir Mrozek
# 94                                                                 NaN
# 95                     Text(e): Molly stirbt Autor(en): Samuel Beckett
# 96                                                                 NaN
# 97                     Text(e): Die Hochzeit Autor(en): Bertolt Brecht
# 98                                                                 NaN
# 99      Text(e): Tagebuch eines Wahnsinnigen Autor(en): Nikolaij Gogol
# 100                                                                NaN
# 101                                                                NaN
# 102                                                                NaN
# 103                                                                NaN
# 104                                                                NaN
# 105                                                                NaN
# 106                                                                NaN
# 107                                                                NaN
# 108                                                                NaN
# 109                                                                NaN
# 110  Text(e): Die Horatier und die Kuriatier Autor(en): Bertolt Brecht
# 111                                                                NaN
# 112                                                                NaN
# 113                                                                NaN
# 114                                                                NaN
# 115                                                                NaN
# 116                                                                NaN
# 117                                                                NaN
# 118      Text(e): Legende vom toten Soldaten Autor(en): Bertolt Brecht
# 119                                                                NaN
# 120                                                                NaN
# 121                                                                NaN
#
# [122 rows x 44 columns]

# %%
## prod -> sheet.tdf in sheet_list
## mapping -> mapping_list[sdx]
## for sdx, sheet in enumerate(sheet_list):
## for rdx, row in sheet_list[sdx].tdf.iterrows
for sdx, sheet in enumerate(sheet_list):
    
    tdf = sheet.tdf
    mapping = mapping_list[sdx]
    graph = sheet.graph
    
    # Iteration durch die Zeilen eines Sheets, row ist eine ganze Zeile 
    for rdx, row in tdf.iterrows(): 
        
        # pro Spalte pro Zeile, column ist der Wert einer Spalte pro Zeile
        for cdx, column in enumerate(row): 

            #Setup der Variablen
            rdfsubj = mapping.titledict[tdf.columns[cdx]][1]
            objclass = mapping.titledict[tdf.columns[cdx]][2]
            rdfprop = mapping.titledict[tdf.columns[cdx]][3]
            objtype = mapping.titledict[tdf.columns[cdx]][5]

            # alle rdfproperties sind in Listen gespeichert, wenn nicht Liste dann NaN
            if tdf.columns[cdx] in list(mapping.title) and isinstance(rdfprop, list): 
                
                # pro Property der Spalte
                for pdx, prop in enumerate(rdfprop): 
                    
                    # nur wenn ein anderes Subjekt in Meta_Py angegeben wird, wird idid angepasst
                    if isinstance(rdfsubj, str) and (isinstance(column, str) or isinstance(column, list)):
                        if isinstance(tdf[rdfsubj][rdx], list):
                            idid = tdf[rdfsubj][rdx][0]
                    else:
                        idid = tdf[mapping.sheetid][rdx][0]
                    
                    #str sind nicht als Liste gespeichert, objtype könnte man noch erweitern auf liste von Länderbezeichungen und Datentypen
                    if isinstance(column, str): 
                        if objtype == "de" or objtype == "en":
                            language = objtype
                        else:
                            language = None  
                        graph.add((nvt[idid], prop, Literal(column, lang=language)))

                    if isinstance(column, list): # References sind als Listen gespeichert
                        for rdfobj in column:
                            if idid != rdfobj:
                                graph.add((nvt[idid], prop, nvt[rdfobj]))
                            if isinstance(objclass, list):
                                for iobjclass in objclass:
                                    graph.add((nvt[rdfobj], rdf.type, iobjclass))
                                

    #               if isinstance(column, list) and isinstance(objclass, list): # für zusätzliche Klassenzugehörigkeit (Bourgeoisie, Proletariat)
    #                   triple_object = column[0] # dem Wert der Spalte wird eine Klasse zugewiesen
    #                   for iobjclass in objclass:
    #                       graph.add((nvt[triple_object], prop, iobjclass))

# %%
with open('nvt_ds_' + str(time) + '.trig', 'wb') as f_trig:
    f_trig.write(nvt_ds.serialize(format="trig"))

# %%
col_ref["Objekte VIDEOS"].tdf
# Out:
#    Digitalisiert visibility level     Projekt ID           andere IDs  \
# 0              1                0      [vid_001]            MCB-TV-25
# 1              1                0      [vid_002]                  NaN
# 2              1                0  [vid_002_001]                  NaN
# 3              1                0  [vid_002_002]           MCB-DV-687
# 4              1                0  [vid_002_003]                  NaN
# 5              1                0  [vid_002_004]                  NaN
# 6              1                0      [vid_003]          MCB-SV-1415
# 7              1                0      [vid_004]                  NaN
# 8              1                0  [vid_004_001]                  NaN
# 9              1                0  [vid_004_002]                  NaN
# 10             1                0  [vid_004_003]                  NaN
# 11             1                0  [vid_004_004]                  NaN
# 12             1                0  [vid_004_005]                  NaN
# 13             1                0      [vid_005]           MCB-TV-788
# 14             1                0      [vid_006]             MCB-TV-1
# 15             1                0      [vid_007]           MCB-SV-462
# 16             1                0      [vid_008]           MCB-SV-186
# 17             1                0  [vid_008_001]           MCB-SV-186
# 18             1                0  [vid_008_002]                  NaN
# 19             1                0  [vid_008_003]                  NaN
# 20             1                0      [vid_009]                  NaN
# 21             1                0  [vid_009_001]  MCB-TV-23;MCB-TV-24
# 22             1                0  [vid_009_002]                  NaN
# 23             1                0      [vid_010]            MCB-TV-22
# 24             1                0  [vid_010_001]                  NaN
# 25             1                0  [vid_010_002]                  NaN
# 26             1                0      [vid_011]            MCB-TV-46
# 27             1                0  [vid_011_001]                  NaN
# 28             1                0      [vid_012]           MCB-TV-303
# 29             1                0      [vid_013]           MCB-TV-305
# ..           ...              ...            ...                  ...
# 38             1                0  [vid_017_001]           MCB-TV-275
# 39             1                0  [vid_017_002]           MCB-TV-275
# 40             1                0      [vid_018]           MCB-TV-321
# 41             1                0      [vid_019]           MCB-TV-740
# 42             1                0  [vid_019_001]           MCB-TV-740
# 43             1                0  [vid_019_002]           MCB-TV-740
# 44             1                0  [vid_019_003]           MCB-TV-740
# 45             1                0  [vid_019_004]           MCB-TV-740
# 46             1                0      [vid_020]                  NaN
# 47             1                0  [vid_020_001]           MCB-TV-550
# 48             1                0  [vid_020_002]                  NaN
# 49             1                0  [vid_020_003]                  NaN
# 50             1                0      [vid_021]           MCB-TV-734
# 51             1                0      [vid_022]           MCB-TV-363
# 52             1                0  [vid_022_001]           MCB-TV-363
# 53             1                0  [vid_022_002]           MCB-TV-363
# 54             1                0  [vid_022_003]           MCB-TV-363
# 55             1                0      [vid_024]            MCB-TV-76
# 56             1                0      [vid_025]           MCB-TV-745
# 57             1                0      [vid_026]           MCB-TV-627
# 58             1                0      [vid_027]                  NaN
# 59             1                0      [vid_028]           MCB-TV-215
# 60             1                0      [vid_029]              MCB-214
# 61             1                0      [vid_030]                  NaN
# 62             1                0  [vid_030_001]                  NaN
# 63             1                0  [vid_030_002]                  NaN
# 64             1                0  [vid_030_003]                  NaN
# 65             1                0      [vid_031]                  NaN
# 66             1                0      [vid_032]                  NaN
# 67             1                0   [vid_11_002]                  NaN
#
#    Standort MCB  \
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# ..          ...
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# 55          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 61          NaN
# 62          NaN
# 63          NaN
# 64          NaN
# 65          NaN
# 66          NaN
# 67          NaN
#
#                                                                                        Kommentar Inhalt  \
# 0                                                                                                   NaN
# 1                                                                                                   NaN
# 2                                                                                                   NaN
# 3                                                                                                   NaN
# 4                                                                                                   NaN
# 5                                                                                                   NaN
# 6                                                                                                   NaN
# 7                                                                                                   NaN
# 8                                                                                                   NaN
# 9                                                                                                   NaN
# 10                                                                                                  NaN
# 11                                                                                                  NaN
# 12                                                                                                  NaN
# 13                                                                                                  NaN
# 14                                                                                                  NaN
# 15                                                                                                  NaN
# 16                                                                                                  NaN
# 17                                                                                                  NaN
# 18                                                                                                  NaN
# 19                                                                                                  NaN
# 20                                                                                                  NaN
# 21                                                                                                  NaN
# 22                                                                                                  NaN
# 23                                                                                                  NaN
# 24                                                                                                  NaN
# 25                                                                                                  NaN
# 26                                                                                                  NaN
# 27                                                                                                  NaN
# 28                                                                                                  NaN
# 29                                                                                                  NaN
# ..                                                                                                  ...
# 38                                                                                                  NaN
# 39                                                                                                  NaN
# 40                                                                                                  NaN
# 41                                                                                                  NaN
# 42                                                                                                  NaN
# 43  Vermutlich handelt es sich um Antagon: Plastik - bin aber nicht ganz sicher (Vgl. Bandbeschriftung)
# 44                                                                                                  NaN
# 45                                                       Einflüsse von Breakdance in dieser produktion?
# 46                                                                                                  NaN
# 47                                                                                                  NaN
# 48                                                                                                  NaN
# 49                                                                                                  NaN
# 50                                                                                                  NaN
# 51                                                                                                  NaN
# 52                                                                                                  NaN
# 53                                                                                                  NaN
# 54                                                                                                  NaN
# 55                                                                                                  NaN
# 56                                                                                                  NaN
# 57                                                       Einflüsse von Breakdance in dieser produktion?
# 58                                                                                                  NaN
# 59                                                                                                  NaN
# 60                                                                                                  NaN
# 61                                                                                                  NaN
# 62                                                                                                  NaN
# 63                                                                                                  NaN
# 64                                                                                                  NaN
# 65                                                                                                  NaN
# 66                                                                                                  NaN
# 67                                                                                                  NaN
#
#                                                          Kommentar Bearbeitung  \
# 0                                                                          NaN
# 1                                                                          NaN
# 2                                                                          NaN
# 3                                                                          NaN
# 4                                                                          NaN
# 5                                                                          NaN
# 6                                                                          NaN
# 7                                                                          NaN
# 8                                                                          NaN
# 9                                                                          NaN
# 10                                                                         NaN
# 11                                                                         NaN
# 12                                                                         NaN
# 13                                                                         NaN
# 14                                                                         NaN
# 15                                                                         NaN
# 16                                                                         NaN
# 17                                                                         NaN
# 18                                                                         NaN
# 19                                                                         NaN
# 20                                                                         NaN
# 21                                                                         NaN
# 22                                                                         NaN
# 23                                                                         NaN
# 24                                                                         NaN
# 25                                                                         NaN
# 26                                                                         NaN
# 27                                                                         NaN
# 28                                                                         NaN
# 29                                                                         NaN
# ..                                                                         ...
# 38  Auf MCB-TV-275 auch Master von Habbe&Meik (MCB-TV-2599, siehe vid-017-002)
# 39                                                                         NaN
# 40                                                                         NaN
# 41                                                                         NaN
# 42                                                                         NaN
# 43                                                                         NaN
# 44                                                                         NaN
# 45                                    Nicht das Masterband, Master ist vid-023
# 46                                                                         NaN
# 47              Masterband für alle drei MCB-TV-550, MCB-TV-551 und MCB-TV-552
# 48                                                                         NaN
# 49                                                                         NaN
# 50                                                                         NaN
# 51                                                                         NaN
# 52                                                                         NaN
# 53                                                                         NaN
# 54                                                                         NaN
# 55                                                                      Master
# 56                                                                      Master
# 57                                                                         NaN
# 58                                                                         NaN
# 59                                                                      Master
# 60                                                                      Master
# 61                                                                      Master
# 62                                                                         NaN
# 63                                                                         NaN
# 64                                                                         NaN
# 65                                                                      Master
# 66                                                                         NaN
# 67                                                                         NaN
#
#    Archivalientyp Unterobjekt von Serie / Abfolge  ... Dateiformat Copyright  \
# 0     [av_objekt]             NaN             NaN  ...         NaN       NaN
# 1     [av_objekt]             NaN             NaN  ...         NaN       NaN
# 2     [av_objekt]       [vid_002]             NaN  ...         NaN       NaN
# 3     [av_objekt]       [vid_002]             NaN  ...         NaN       NaN
# 4     [av_objekt]       [vid_002]             NaN  ...         NaN       NaN
# 5     [av_objekt]       [vid_002]             NaN  ...         NaN       NaN
# 6     [av_objekt]             NaN             NaN  ...         NaN       NaN
# 7             NaN             NaN             NaN  ...         NaN       NaN
# 8     [av_objekt]       [vid_004]             NaN  ...         NaN       NaN
# 9     [av_objekt]       [vid_004]             NaN  ...         NaN       NaN
# 10    [av_objekt]       [vid_004]             NaN  ...         NaN       NaN
# 11    [av_objekt]       [vid_004]             NaN  ...         NaN       NaN
# 12    [av_objekt]       [vid_004]             NaN  ...         NaN       NaN
# 13    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 14    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 15    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 16            NaN             NaN             NaN  ...         NaN       NaN
# 17    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 18    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 19    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 20            NaN             NaN             NaN  ...         NaN       NaN
# 21    [av_objekt]       [vid_009]             NaN  ...         NaN       NaN
# 22    [av_objekt]       [vid_009]             NaN  ...         NaN       NaN
# 23    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 24    [av_objekt]       [vid_010]             NaN  ...         NaN       NaN
# 25    [av_objekt]       [vid_010]             NaN  ...         NaN       NaN
# 26    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 27    [av_objekt]       [vid_011]             NaN  ...         NaN       NaN
# 28    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 29    [av_objekt]             NaN             NaN  ...         NaN       NaN
# ..            ...             ...             ...  ...         ...       ...
# 38    [av_objekt]       [vid_017]             NaN  ...         NaN       NaN
# 39    [av_objekt]       [vid_017]             NaN  ...         NaN       NaN
# 40    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 41    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 42    [av_objekt]       [vid_019]             NaN  ...         NaN       NaN
# 43    [av_objekt]       [vid_019]             NaN  ...         NaN       NaN
# 44    [av_objekt]       [vid_019]             NaN  ...         NaN       NaN
# 45    [av_objekt]       [vid_019]             NaN  ...         NaN       NaN
# 46            NaN             NaN             NaN  ...         NaN       NaN
# 47    [av_objekt]       [vid_020]             NaN  ...         NaN       NaN
# 48    [av_objekt]       [vid_020]             NaN  ...         NaN       NaN
# 49    [av_objekt]       [vid_020]             NaN  ...         NaN       NaN
# 50    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 51    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 52    [av_objekt]       [vid_022]             NaN  ...         NaN       NaN
# 53    [av_objekt]       [vid_022]             NaN  ...         NaN       NaN
# 54    [av_objekt]       [vid_022]             NaN  ...         NaN       NaN
# 55    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 56    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 57    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 58    [av_objekt]             NaN             NaN  ...         NaN       NaN
# 59            NaN             NaN             NaN  ...         NaN       NaN
# 60            NaN             NaN             NaN  ...         NaN       NaN
# 61            NaN             NaN             NaN  ...         NaN       NaN
# 62            NaN       [vid_030]             NaN  ...         NaN       NaN
# 63            NaN       [vid_030]             NaN  ...         NaN       NaN
# 64            NaN       [vid_030]             NaN  ...         NaN       NaN
# 65            NaN             NaN             NaN  ...         NaN       NaN
# 66            NaN             NaN             NaN  ...         NaN       NaN
# 67    [av_objekt]       [vid_011]             NaN  ...         NaN       NaN
#
#    Dateipfad Master Rechtesitutation  \
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN
# 11              NaN              NaN
# 12              NaN              NaN
# 13              NaN              NaN
# 14              NaN              NaN
# 15              NaN              NaN
# 16              NaN              NaN
# 17              NaN              NaN
# 18              NaN              NaN
# 19              NaN              NaN
# 20              NaN              NaN
# 21              NaN              NaN
# 22              NaN              NaN
# 23              NaN              NaN
# 24              NaN              NaN
# 25              NaN              NaN
# 26              NaN              NaN
# 27              NaN              NaN
# 28              NaN              NaN
# 29              NaN              NaN
# ..              ...              ...
# 38              NaN              NaN
# 39              NaN              NaN
# 40              NaN              NaN
# 41              NaN              NaN
# 42              NaN              NaN
# 43              NaN              NaN
# 44              NaN              NaN
# 45              NaN              NaN
# 46              NaN              NaN
# 47              NaN              NaN
# 48              NaN              NaN
# 49              NaN              NaN
# 50              NaN              NaN
# 51              NaN              NaN
# 52              NaN              NaN
# 53              NaN              NaN
# 54              NaN              NaN
# 55              NaN              NaN
# 56              NaN              NaN
# 57              NaN              NaN
# 58              NaN              NaN
# 59              NaN              NaN
# 60              NaN              NaN
# 61              NaN              NaN
# 62              NaN              NaN
# 63              NaN              NaN
# 64              NaN              NaN
# 65              NaN              NaN
# 66              NaN              NaN
# 67              NaN              NaN
#
#                                                                                                                                 Beschreibung_Quelle  \
# 0   Klangbilder - fünf Inszenierungen von Marie-Luise Anger: "Die offene Tür", "Studie", "Kanon und Fuge" (Co-Regie Katrin Adams) "Le Violoncell...
# 1                                                                                                                                               NaN
# 2   Auf Bühne stehen fünf zylinderförmige Röhren, die beginnen, sich über die Bühne zu bewegen. Ihnen entsteigen nach und nach beinahe nackte Da...
# 3   Solo des japanischen Butho-Tänzers Mitsuru Sasaki. Eine Aufführung im Rahmen der Gestischen Woche 1989 in Berlin. Quelle: TN;http://archiv.m...
# 4                                                                              Solopantomime einer Darstellerin. Sie nimmt verschiedene Rollen ein.
# 5                                                                              Solopantomime einer Darstellerin. Sie nimmt verschiedene Rollen ein.
# 6   „Die Horatier und die Kuriatier“ - Ein Lehrstück von Bertolt Brecht. Eine Produktion des Pantomimentheater vom Prenzlauer Berg, die in den 1...
# 7                                                                                                                                               NaN
# 8   Eine mime corporel-Produktion des französischen Duos Theatre de l'Ange Fou. Gastspiel bei der Woche des gestischen Theaters 1987. Darin arbe...
# 9   Ein Bewegungstheaterstück für acht Spieler zum Thema Erschliessung der Welt: Die Hoffnungen, Sehnsüchte, Nöte und Träume von acht Menschen, ...
# 10                                                                                                                   Solo ohne Text des Clown Smol.
# 11  Diverse Ausschnitte aus TV-Programmen, Aufnahmen von Open-Air Vorstellungen der Gruppe Licedei. Vermutlich asl Demo für die Woche des Gestis...
# 12  Ein genreübergreifendes Stück mit Menschen in Klettanzügen; Mime Corporel, Slapstick, Performance, Comedy, Bildertheater... \n\nEine frühe I...
# 13  Ein genreübergreifendes Stück mit Menschen in Klettanzügen; Mime Corporel, Slapstick, Performance, Comedy, Bildertheater... \n\nEine frühe I...
# 14  Ein Bewegungstheaterstück für acht Spieler zum Thema Erschliessung der Welt: Die Hoffnungen, Sehnsüchte, Nöte und Träume von acht Menschen, ...
# 15                                                                                                                                              NaN
# 16                                                                                                                                              NaN
# 17  Fernseh-Dokumentation und Arbeitsdemonstration von Corinne Soum, ehemalige Assistentin von Decroux und Ulrike Koennecke, Schülerin an der Ec...
# 18  Die Horatier und die Kuriatier - Ein Lehrstück von Bertolt Brecht. Eine Produktion des Pantomimentheater vom Prenzlauer Berg, die in den 198...
# 19                                                                                                                                              NaN
# 20                                                                                                                                              NaN
# 21  Eine mime corporel-Produktion des französischen Duos Theatre de l'Ange Fou. Gastspiel bei der Woche des gestischen Theaters 1987. Darin arbe...
# 22  Ein Bewegungstheaterstück für acht Spieler zum Thema Erschliessung der Welt: Die Hoffnungen, Sehnsüchte, Nöte und Träume von acht Menschen, ...
# 23                                                                                                                                              NaN
# 24                                                                                                                                              NaN
# 25    Eine Produktion des Theatre de l'ange fou. Die Aufnahme entstand während eines Gastspiels bei der Woche des Gestischen Theaters im Juli 1990.
# 26                                                                                                                                              NaN
# 27  Edierte Aufnahme, die evtl. nicht eine gesamte Aufführung zeigt. Am Ende der Aufnahme erscheint ein Abspann, der sie als eine Produktion des...
# 28  Unedierte Aufnahme einer Aufführung, ohne Schlussapplaus. Es existiert eine Kurzfassung mit nur 30 Minuten Laufzeit. Beide zeigen vermutlich...
# 29                                                                                                                                              NaN
# ..                                                                                                                                              ...
# 38  Aufnahme einer gesamten Aufführung bei der Woche des Gestischen Theaters 1989, mit Schlussapplaus. Die Aufnahme ist sehr dunkel. Quelle: TN;...
# 39                         Das Band zeigt eine gesamte Aufführung, mit Einzug der Darsteller durch den Zuschauerraum und Schlussapplaus. Quelle: TN
# 40  Soloprogramm von Benito Gutmacher bei der Woche des Gestischen Theaters 1989. Das Band zeigt die gesamte Aufführung mit Schlussapplaus. Am E...
# 41                                                                                                                                              NaN
# 42                                                                                                                                       Quelle: TN
# 43                 Eine Aufführung im Rahmen der Woche des Gestischen Theater 1987. Die Aufnahme zeigt vermutlich die gesamte Aufführung Quelle: TN
# 44  Eine Aufführung im Rahmen der Woche des Gestischen Theater 1987. Die Aufnahme zeigt vermutlich die gesamte Aufführung, allerdings ohne Schlu...
# 45  Die Aufzeichnung zeigt vermutlich eine ganze Aufführung. Allerdings ist kein Publikum zu sehen, der Anfang ist sehr abrupt und es fehlt der ...
# 46                                                                                                                                              NaN
# 47  Edierte Aufzeichnung dreier Produktionen der Gruppe Movers (beautiFOOLS, BABYZARR, 7 Soli) Künstlerische Leitung und Regie: Christian Mattis...
# 48  Edierte Aufzeichnung dreier Produktionen der Gruppe Movers (beautiFOOLS, BABYZARR, 7 Soli) Künstlerische Leitung und Regie: Christian Mattis...
# 49  Edierte Aufzeichnung dreier Produktionen der Gruppe Movers (beautiFOOLS, BABYZARR, 7 Soli) Künstlerische Leitung und Regie: Christian Mattis...
# 50  Unedierte Aufzeichnung eines Gastspiels bei der Woche des Gestischen Theaters 1989. Zu sehen ist die gesamte Aufführung mit Schlussapplaus. ...
# 51                                                                                                                                              NaN
# 52                                                                                                                                              NaN
# 53                                                              Die Aufzeichnung zeigt vermutlich eine vollständige Aufführung, mit Schlussapplaus.
# 54  Aufzeichnung von Proben zur Produktion "Schaum" des Pantomimentheater vom Prenzlauer Berg. Die Darsteller*innen tragen noch nicht die Kostüm...
# 55  Aufzeichnung eines Soloprogramms des Pantomimen Philippe Bizot, vermutlich bei der Woche des Gestischen Theaters 1987 in Ostberlin entstande...
# 56                                                                                                                                       Quelle: TN
# 57  Die Aufzeichnung zeigt vermutlich eine ganze Aufführung. Allerdings ist kein Publikum zu sehen, der Anfang ist sehr abrupt und es fehlt der ...
# 58              Die Aufnahme entstand im Auftrag des Niederländischen Mime Centrums, vermutlich bei einem Gastspiel in den Niederlanden. Quelle: TN
# 59              Die Aufnahme entstand im Auftrag des Niederländischen Mime Centrums, vermutlich bei einem Gastspiel in den Niederlanden. Quelle: TN
# 60  Die Aufnahme entstand im Auftrag des Niederländischen Mime Centrums, vermutlich bei einem Gastspiel in den Niederlanden. Nach Ende der Aufze...
# 61                                                                                                                                       Quelle: TN
# 62                                                                                                          Edierte Aufnahme mit Titeln. Quelle: TN
# 63                                                                                Gesamte Aufnahme einer Aufführung, mit Schlussapplaus. Quelle: TN
# 64                                                                                              Aufzeichnung mit erheblichem Bildfehler. Quelle: TN
# 65  Werkstattprogramm des Pantomimentheater vom Prenzlauer Berg., Gruppenchoreografien und Einzel- sowie Partnerszenen mit Musik und wenigen Req...
# 66  Eine Produktion des DEFA-Studios für Kurzfilm in Zusammenarbeit mit dem Pantomimenstudio Berlin unter der Leitung von Eberhard Kube. Ein Kur...
# 67  Edierte Aufnahme einer [oder mehrerer] Aufführung[en] ohne Sprache. Darüber liegt ein niederländischer Off-Kommentar. Am Anfang dieser Aufna...
#
#                                                                                                            Zustand_Datum  \
# 0                                                                                                                    NaN
# 1                                                                                              Zustand: Bild gelbstichig
# 2                                                                                              Zustand: Bild gelbstichig
# 3                                                                                              Zustand: Bild gelbstichig
# 4                                                                                              Zustand: Bild gelbstichig
# 5                                                                                              Zustand: Bild gelbstichig
# 6                                                                                                                    NaN
# 7                                                                                                                    NaN
# 8                                                                                                                    NaN
# 9                                                                                                                    NaN
# 10                                                                                                                   NaN
# 11                                                                                                                   NaN
# 12                                                   Zustand: Kontrast zu schwach, der Vor- und Abspann sind unleserlich
# 13                                                                                                                   NaN
# 14                                                                                                                   NaN
# 15                                                                                        Zustand: niedrige Bildqualität
# 16                                                                                                                   NaN
# 17                                                                                                                   NaN
# 18                                                                                                                   NaN
# 19                                        Zustand: niedrige Bildqualität, zweitwilig setzt das Bild aus, dann nur audio.
# 20                                                                                                                   NaN
# 21                                                            Zustand: niedrige Bildqualität, Ton übersteuert bisweilen.
# 22                                                            Zustand: niedrige Bildqualität, Ton übersteuert bisweilen.
# 23                                                                                                                   NaN
# 24                                                            Zustand: niedrige Bildqualität, Ton übersteuert bisweilen.
# 25                                                            Zustand: niedrige Bildqualität, Ton übersteuert bisweilen.
# 26                                                                                                                   NaN
# 27                                                                                                                   NaN
# 28                                                                                        Zustand: niedrige Bildqualität
# 29                                                                                                                   NaN
# ..                                                                                                                   ...
# 38                                                                                                                   NaN
# 39                                                        Zustand: Bild ist grünstichig, Band enthält wenige Bildfehler.
# 40                                                                                        Zustand: niedrige Bildqualität
# 41                                                                                                                   NaN
# 42                                                                                                                   NaN
# 43                                                                                                                   NaN
# 44                                                                                                                   NaN
# 45                                                                                                                   NaN
# 46                                                                                        Zustand: Niedrige Bildqualität
# 47                                                                                                                   NaN
# 48                                                                                                                   NaN
# 49                                                                                                                   NaN
# 50  Zustand: Bild ist zweitweise gelb- bzw. grünstichig. Die Bildqualität ist sehr niedrig. ZU Beginn fehlt [?] der Ton.
# 51                                                                                                                   NaN
# 52                                                         Zustand: Bild ist grünstichig. Bildqualität ist sehr niedrig.
# 53                                                               Zustand: sehr niedrige Bildqualität, leichter Rotstich.
# 54                                                                                                Zustand: Bild ist s/w.
# 55                                                Zustand: Niedrige Bildqualität, teilweise grünstichig, Ton übersteuert
# 56                                                                        Zustand: Niedrige Bildqualität, Ton sehr leise
# 57                                                                                                                   NaN
# 58                                                                                        Zustand: Niedrige Bildqualität
# 59                                                                                        Zustand: Niedrige Bildqualität
# 60                                                                                       Zustand: Niedrige Bildqualität.
# 61                                                                                                                   NaN
# 62                                                                                                                   NaN
# 63                                                                                                                   NaN
# 64                                                                                        Zustand: Niedrige Bildqualität
# 65                                                                                   Zustand: Sehr niedrige Bildqualität
# 66                                                                                                                   NaN
# 67                                                                                                                   NaN
#
#            Phys_ID       Phys_Type Digi_ID Digi_Type
# 0   [phys_vid_001]  [phys_vid_001]     NaN       NaN
# 1   [phys_vid_002]  [phys_vid_002]     NaN       NaN
# 2              NaN             NaN     NaN       NaN
# 3              NaN             NaN     NaN       NaN
# 4              NaN             NaN     NaN       NaN
# 5              NaN             NaN     NaN       NaN
# 6   [phys_vid_003]  [phys_vid_003]     NaN       NaN
# 7   [phys_vid_004]  [phys_vid_004]     NaN       NaN
# 8              NaN             NaN     NaN       NaN
# 9              NaN             NaN     NaN       NaN
# 10             NaN             NaN     NaN       NaN
# 11             NaN             NaN     NaN       NaN
# 12             NaN             NaN     NaN       NaN
# 13  [phys_vid_005]  [phys_vid_005]     NaN       NaN
# 14  [phys_vid_006]  [phys_vid_006]     NaN       NaN
# 15  [phys_vid_007]  [phys_vid_007]     NaN       NaN
# 16  [phys_vid_008]  [phys_vid_008]     NaN       NaN
# 17             NaN             NaN     NaN       NaN
# 18             NaN             NaN     NaN       NaN
# 19             NaN             NaN     NaN       NaN
# 20  [phys_vid_009]  [phys_vid_009]     NaN       NaN
# 21             NaN             NaN     NaN       NaN
# 22             NaN             NaN     NaN       NaN
# 23  [phys_vid_010]  [phys_vid_010]     NaN       NaN
# 24             NaN             NaN     NaN       NaN
# 25             NaN             NaN     NaN       NaN
# 26  [phys_vid_011]  [phys_vid_011]     NaN       NaN
# 27             NaN             NaN     NaN       NaN
# 28  [phys_vid_012]  [phys_vid_012]     NaN       NaN
# 29  [phys_vid_013]  [phys_vid_013]     NaN       NaN
# ..             ...             ...     ...       ...
# 38             NaN             NaN     NaN       NaN
# 39             NaN             NaN     NaN       NaN
# 40  [phys_vid_018]  [phys_vid_018]     NaN       NaN
# 41  [phys_vid_019]  [phys_vid_019]     NaN       NaN
# 42             NaN             NaN     NaN       NaN
# 43             NaN             NaN     NaN       NaN
# 44             NaN             NaN     NaN       NaN
# 45             NaN             NaN     NaN       NaN
# 46  [phys_vid_020]  [phys_vid_020]     NaN       NaN
# 47             NaN             NaN     NaN       NaN
# 48             NaN             NaN     NaN       NaN
# 49             NaN             NaN     NaN       NaN
# 50  [phys_vid_021]  [phys_vid_021]     NaN       NaN
# 51  [phys_vid_022]  [phys_vid_022]     NaN       NaN
# 52             NaN             NaN     NaN       NaN
# 53             NaN             NaN     NaN       NaN
# 54             NaN             NaN     NaN       NaN
# 55  [phys_vid_024]  [phys_vid_024]     NaN       NaN
# 56  [phys_vid_025]  [phys_vid_025]     NaN       NaN
# 57  [phys_vid_026]  [phys_vid_026]     NaN       NaN
# 58  [phys_vid_027]  [phys_vid_027]     NaN       NaN
# 59  [phys_vid_028]  [phys_vid_028]     NaN       NaN
# 60  [phys_vid_029]  [phys_vid_029]     NaN       NaN
# 61  [phys_vid_030]  [phys_vid_030]     NaN       NaN
# 62             NaN             NaN     NaN       NaN
# 63             NaN             NaN     NaN       NaN
# 64             NaN             NaN     NaN       NaN
# 65  [phys_vid_031]  [phys_vid_031]     NaN       NaN
# 66  [phys_vid_032]  [phys_vid_032]     NaN       NaN
# 67             NaN             NaN     NaN       NaN
#
# [68 rows x 72 columns]

# %%
colcol = ["A", "B", "C"]
rowrow = ["D", "E", "F"]
datedate = np.array([["1 ", "asdasd2     ", "    2"], ["asdasd2     ", "1 ", "    2"],[ "    2", "1 ", "asdasd2     "]])
testdf = pd.DataFrame(data=datedate, index=rowrow, columns=colcol)

# %%
testdf.applymap(str.strip)
# Out:
#          A        B        C
# D        1  asdasd2        2
# E  asdasd2        1        2
# F        2        1  asdasd2
