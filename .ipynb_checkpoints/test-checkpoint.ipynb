# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('./NVT_Metadatentabelle_MASTER.xlsm')

# %%
df.values
# Out:
# array([['Identifier / geeinigter Name', 'Produktionsname / Titel',
#         'Beschreibung', ..., 'Veranstaltungsort', 'Stadt', 'Land'],
#        ['eigener Identifier', 'Text', 'Text', ..., 'Referenz',
#         'Referenz', 'Referenz'],
#        [nan, 'Produktionstitel…?', nan, ..., 'Name des Ortes', nan, nan],
#        ...,
#        ['PR_Silberner_Wind', 'Silberner Wind / Stríbrný vítr', nan, ...,
#         'LOC_Theater_Gans_an_der_Schnur', 'Bruenn', 'Tschechoslowakei'],
#        ['PR_Svatba', 'Die Hochzeit / Svatba', nan, ...,
#         'LOC_Theater_Gans_an_der_Schnur', 'Bruenn', 'Tschechoslowakei'],
#        ['PR_Horatier_Kuriatier', 'Die Horatier und die Kuriatier',
#         'Textfassung von Eberhard Kube und Herbert de Lamboy nach dem gleichnamigen Lehrstück von Betolt Brecht. Das Stück wurde zunächst unter dem Titel "Viele Dinge sind in einem Ding" aufgeführt, später erfolgten Freiluftaufführungen. ',
#         ..., nan, nan, nan]], dtype=object)

# %%
xl = pd.ExcelFile('./NVT_Metadatentabelle_MASTER.xlsm')

xl.sheet_names  # see all sheet names
# Out:
# ['Produktionen',
#  'Ereignisse',
#  'Objekte VIDEOS',
#  'Objekte TEXT',
#  'Objekte BILD',
#  'Objekte AUDIO',
#  '||_Personen',
#  '||_Gruppen_Ensembles',
#  '||_Veranstaltungsort',
#  '||_Städte',
#  '||_Länder',
#  'Sammlungen',
#  'Serie',
#  'TYPEN und GLOSSARE',
#  'Fragen und Dok',
#  'TODOs',
#  'Legende',
#  'Unterobjekt Beispiele',
#  'Übersicht']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 35 columns):
# Basisinformationen                                                  101 non-null object
# Unnamed: 1                                                          101 non-null object
# Unnamed: 2                                                          52 non-null object
# Unnamed: 3                                                          47 non-null object
# Unnamed: 4                                                          6 non-null object
# Unnamed: 5                                                          9 non-null object
# Unnamed: 6                                                          13 non-null object
# AGENTEN (gültig für die gesamte Produktion bzw. alle Ereignisse)    71 non-null object
# Unnamed: 8                                                          29 non-null object
# Unnamed: 9                                                          4 non-null object
# ...

# %%
events = pd.read_excel('./NVT_Metadatentabelle_MASTER.xlsm', sheet_name='Ereignisse')

# %%
events
# Out:
#                             Basisinformationen  \
# 0                 Identifier / geeinigter Name
# 1                           eigener Identifier
# 2             EV_12_Traeume_des_Dr_Fridkin_001
# 3             EV_12_Traeume_des_Dr_Fridkin_002
# 4             EV_12_Traeume_des_Dr_Fridkin_003
# 5             EV_Aber_macht_keine_Dummheit_001
# 6             EV_Aber_macht_keine_Dummheit_002
# 7                        EV_Aikido_GW_1986_001
# 8                               EV_Amapola_001
# 9                             EV_Ameriques_001
# 10                 EV_Aufstand_der_Traeume_002
# 11                  EV_Aufstand_der_Träume_001
# 12                        EV_August_August_001
# 13                        EV_August_August_002
# 14                        EV_August_August_003
# 15                        EV_Avant_Theater_001
# 16                        EV_Avant_Theater_002
# 17                            EV_Baustelle_001
# 18                            EV_Baustelle_002
# ...

# %%
productions = pd.read_excel('./NVT_Metadatentabelle_MASTER.xlsm', sheet_name='Ereignisse')

# %%
productions = pd.read_excel('./NVT_Metadatentabelle_MASTER.xlsm', sheet_name='Produktionen')
productions.head()
# Out:
#                                   Basisinformationen  \
# 0                       Identifier / geeinigter Name
# 1                                 eigener Identifier
# 2                                                NaN
# 3  PR_Internationaler_Workshop_zur_Biomechanik_GI...
# 4                       PR_12_Traeume_des_Dr_Fridkin
#
#                   Unnamed: 1  \
# 0    Produktionsname / Titel
# 1                       Text
# 2         Produktionstitel…?
# 3                        NaN
# 4  12 Träume des Dr. Fridkin
#
#                                           Unnamed: 2  \
# 0                                       Beschreibung
# 1                                               Text
# 2                                                NaN
# 3                                                NaN
# 4  Produktion des Mime-Theater "Version" aus Tsch...
#
#                                           Unnamed: 3        Unnamed: 4  \
# ...

# %%
productions = pd.read_excel('./NVT_Metadatentabelle_MASTER.xlsm', sheet_name='Produktionen', header=1)
productions.head()
# Out:
#                         Identifier / geeinigter Name  \
# 0                                 eigener Identifier
# 1                                                NaN
# 2  PR_Internationaler_Workshop_zur_Biomechanik_GI...
# 3                       PR_12_Traeume_des_Dr_Fridkin
# 4                                         PR_Amapola
#
#      Produktionsname / Titel  \
# 0                       Text
# 1         Produktionstitel…?
# 2                        NaN
# 3  12 Träume des Dr. Fridkin
# 4                    Amapola
#
#                                         Beschreibung  \
# 0                                               Text
# 1                                                NaN
# 2                                                NaN
# 3  Produktion des Mime-Theater "Version" aus Tsch...
# 4                                                NaN
#
#                                Quelle (Beschreibung) Verwendete Texte  \
# ...

# %%
productions
# Out:
#                           Identifier / geeinigter Name  \
# 0                                   eigener Identifier
# 1                                                  NaN
# 2    PR_Internationaler_Workshop_zur_Biomechanik_GI...
# 3                         PR_12_Traeume_des_Dr_Fridkin
# 4                                           PR_Amapola
# 5                                         PR_Ameriques
# 6                              PR_Aufstand_der_Traeume
# 7                                     PR_August_August
# 8                                      PR_Avat_Theater
# 9                                         PR_Baustelle
# 10                                     PR_beauti_FOOLS
# 11                       PR_Berliner_Ballonfieber_1803
# 12                         PR_Bilder_einer_Ausstellung
# 13                                         PR_Blaubart
# 14                           PR_Bremer_Stadtmusikanten
# 15                                       PR_Cafe_Fatal
# ...

# %%
productions['Identifier / geeinigter Name']
# Out:
# 0                                     eigener Identifier
# 1                                                    NaN
# 2      PR_Internationaler_Workshop_zur_Biomechanik_GI...
# 3                           PR_12_Traeume_des_Dr_Fridkin
# 4                                             PR_Amapola
# 5                                           PR_Ameriques
# 6                                PR_Aufstand_der_Traeume
# 7                                       PR_August_August
# 8                                        PR_Avat_Theater
# 9                                           PR_Baustelle
# 10                                       PR_beauti_FOOLS
# 11                         PR_Berliner_Ballonfieber_1803
# 12                           PR_Bilder_einer_Ausstellung
# 13                                           PR_Blaubart
# 14                             PR_Bremer_Stadtmusikanten
# 15                                         PR_Cafe_Fatal
# ...

# %%
productions['Identifier / geeinigter Name'].dropna()
# Out:
# 0                                     eigener Identifier
# 2      PR_Internationaler_Workshop_zur_Biomechanik_GI...
# 3                           PR_12_Traeume_des_Dr_Fridkin
# 4                                             PR_Amapola
# 5                                           PR_Ameriques
# 6                                PR_Aufstand_der_Traeume
# 7                                       PR_August_August
# 8                                        PR_Avat_Theater
# 9                                           PR_Baustelle
# 10                                       PR_beauti_FOOLS
# 11                         PR_Berliner_Ballonfieber_1803
# 12                           PR_Bilder_einer_Ausstellung
# 13                                           PR_Blaubart
# 14                             PR_Bremer_Stadtmusikanten
# 15                                         PR_Cafe_Fatal
# 16                                         PR_Caoutchouc
# ...

# %%
productions.head()
# Out:
#                         Identifier / geeinigter Name  \
# 0                                 eigener Identifier
# 1                                                NaN
# 2  PR_Internationaler_Workshop_zur_Biomechanik_GI...
# 3                       PR_12_Traeume_des_Dr_Fridkin
# 4                                         PR_Amapola
#
#      Produktionsname / Titel  \
# 0                       Text
# 1         Produktionstitel…?
# 2                        NaN
# 3  12 Träume des Dr. Fridkin
# 4                    Amapola
#
#                                         Beschreibung  \
# 0                                               Text
# 1                                                NaN
# 2                                                NaN
# 3  Produktion des Mime-Theater "Version" aus Tsch...
# 4                                                NaN
#
#                                Quelle (Beschreibung) Verwendete Texte  \
# ...

# %%
productions = productions[np.isfinite(df['EPS'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EPS'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-e0fe2310584b> in <module>
# ----> 1 productions = productions[np.isfinite(df['EPS'])]
# ...
