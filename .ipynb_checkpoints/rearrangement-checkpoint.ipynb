# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
xl = pd.ExcelFile('./NVT_Metadatentabelle_MASTER.xlsm') ## load Excel File to display sheet_names

# %%
xl.sheet_names  ## display sheet_names
# Out:
# ['Produktionen',
#  'Ereignisse',
#  'Objekte VIDEOS',
#  'Objekte TEXT',
#  'Objekte BILD',
#  'Objekte AUDIO',
#  '||_Personen',
#  '||_Gruppen_Ensembles',
#  '||_Veranstaltungsort',
#  '||_Städte',
#  '||_Länder',
#  'Sammlungen',
#  'Serie',
#  'TYPEN und GLOSSARE',
#  'Fragen und Dok',
#  'TODOs',
#  'Legende',
#  'Unterobjekt Beispiele',
#  'Übersicht']

# %%
def merge_columns(df, col1, col2, result=None):
    if result == "season":
        col3 = "Spielzeit"
        df.loc[df[col1].notna() & df[col2].notna(), col3] = "season_" + df["ID"] + "_" + df[col1].apply(str).str[:4] + "_" + pr_clean[col2].apply(str).str[:4]
        df.loc[df[col1].notna() & df[col2].isna(), col3] = "season_" + df["ID"] + "_" + df[col1].apply(str).str[:4]
        df.loc[df[col1].isna() & df[col2].notna(), col3] = "season_" + df["ID"] + "_" + df[col2].apply(str).str[:4]
        return df
    elif result == "description":
        col3 = "BeschreibungQuelle"
        df.loc[df[col1].notna() & df[col2].notna(), col3] = "Beschreibung: " + pr_clean[col1] + " Quelle: " + pr_clean[col2]
        df.loc[df[col1].notna() & df[col2].isna(), col3] = "Beschreibung: " + pr_clean[col1]
        df.loc[df[col1].isna() & df[col2].notna(), col3] = " Quelle: " + pr_clean[col2]
        return df
    elif result == "texts":
        col3 = "Texte_Autoren"
        df.loc[df[col1].notna() & df[col2].notna(), col3] = "Text(e): " + pr_clean[col1] + " Autor(en): " + pr_clean[col2]
        df.loc[df[col1].notna() & df[col2].isna(), col3] = "Text(e): " + pr_clean[col1]
        df.loc[df[col1].isna() & df[col2].notna(), col3] = "Autor(en): " + pr_clean[col2]
        return df
    else:
        print("Wrong Keyword, nothing happened")
        return df

# %%
def refreplace(df):
    df = df.str.lower()
    df = df.str.replace("ä", "ae")
    df = df.str.replace("ö","oe")
    df = df.str.replace("ü","ue")
    df = df.str.replace("ß","ss")
    df = df.str.replace("!?,\.", "")
    df = df.str.replace("[^a-zA-Z0-9]", "_")
    df = df.str.replace("__", "_")
    df = df.str.strip("_")
    return df

# %%
def peoplereplace(df):
    df.str.replace("_","-")
    df.str.replace(",", " ")
    df.str.replace(";", "; ")
    return df

# %%
## events = pd.read_excel('./NVT_Metadatentabelle_MASTER.xlsm', sheet_name='Ereignisse')

# %%
productions = pd.read_excel('./NVT_Metadatentabelle_MASTER.xlsm', sheet_name='Produktionen', header=1) ## load productions sheet with header in row 1 (row 0 is ignored i think)

# %%
pr_clean = (productions[productions['Identifier / geeinigter Name'].str.contains('PR', na=False)] ## drops all rows that don't start with 'PR' or are NaN
           .drop(['Musik (für GEMA)'], axis='columns') ## drops unmodeled column
           .drop([2]) ## drops example row
           .reset_index(drop=True) ## resets index to be continouus
           .rename(columns={'Identifier / geeinigter Name':'ID', ## renames columns for future reference
                                          'Produktionsname / Titel':'PR_Titel',
                                          'Quelle (Beschreibung)':'Q_Beschreibung',
                                          'Verwendete Texte':'Verwendete_Texte',
                                          'Autor(en) der Texte':'Autoren_Texte',
                                          'Beteiligte Gruppen / Compagnies':'Beteiligte_Gruppen',
                                          'Sprecher*in':'SprecherIn',
                                          'Darsteller allgem.':'Darsteller',
                                          'Weitere Mitwirkende':'Mitwirkende',
                                          'Spielzeit / Laufzeit Start':'Spielzeit_Start',
                                          'Spielzeit / Laufzeit Ende':'Spielzeit_Ende'
                           })
           )

# %%
# pr_clean = merge_season(pr_clean, "Spielzeit_Start", "Spielzeit_Ende", "Spielzeit")

# %%
pr_clean = merge_columns(pr_clean, "Spielzeit_Start", "Spielzeit_Ende", result = "season")

# %%
pr_clean = merge_columns(pr_clean, "Beschreibung", "Q_Beschreibung", result = "description")

# %%
pr_clean = merge_columns(pr_clean, "Verwendete_Texte", "Autoren_Texte", result = "texts") 
## in Zukunft müssten die Autoren mit der Personentabelle abgeglichen werden, am besten trotzdem noch als literal

# %%
pr_clean.columns
# Out:
# Index(['ID', 'PR_Titel', 'Beschreibung', 'Q_Beschreibung', 'Verwendete_Texte',
#        'Autoren_Texte', 'Produktionstyp', 'Beteiligte_Gruppen', 'Konzept',
#        'Textbearbeitung', 'Übersetzung', 'Regie', 'SprecherIn',
#        'Choreographie', 'Dramaturgie', 'Bühnenbild', 'Kostümdesgin',
#        'Figurenbau', 'Maskenbau', 'Lichtdesign', 'Videodesign', 'Schauspieler',
#        'Tänzer', 'Darsteller', 'Musiker', 'Komposition', 'Mitwirkende',
#        'Premierendatum', 'Dernierendatum', 'Spielzeit_Start', 'Spielzeit_Ende',
#        'Veranstaltungsort', 'Stadt', 'Land', 'Spielzeit', 'BeschreibungQuelle',
#        'Texte_Autoren'],
#       dtype='object')

# %%
for idx, i in enumerate(pr_clean.columns):
    print([idx, i])
# Out:
# [0, 'ID']
# [1, 'PR_Titel']
# [2, 'Beschreibung']
# [3, 'Q_Beschreibung']
# [4, 'Verwendete_Texte']
# [5, 'Autoren_Texte']
# [6, 'Produktionstyp']
# [7, 'Beteiligte_Gruppen']
# [8, 'Konzept']
# [9, 'Textbearbeitung']
# [10, 'Übersetzung']
# [11, 'Regie']
# [12, 'SprecherIn']
# [13, 'Choreographie']
# [14, 'Dramaturgie']
# [15, 'Bühnenbild']
# [16, 'Kostümdesgin']
# [17, 'Figurenbau']
# [18, 'Maskenbau']
# [19, 'Lichtdesign']
# [20, 'Videodesign']
# [21, 'Schauspieler']
# [22, 'Tänzer']
# [23, 'Darsteller']
# [24, 'Musiker']
# [25, 'Komposition']
# [26, 'Mitwirkende']
# [27, 'Premierendatum']
# [28, 'Dernierendatum']
# [29, 'Spielzeit_Start']
# [30, 'Spielzeit_Ende']
# [31, 'Veranstaltungsort']
# [32, 'Stadt']
# [33, 'Land']
# [34, 'Spielzeit']
# [35, 'BeschreibungQuelle']
# [36, 'Texte_Autoren']

# %%
for idx, i in enumerate(pr_clean.columns):
    if idx == 0:
        print("Referenzliste zum splitten und replacen; I=ID R=reference L=literal N=None\n\nrefreplace für I und R, split für R, erst split dann refreplace\n")
        print(["I", idx, i])
    elif idx in range(6, 27) or idx in range(31, 35):
        print(["R", idx, i])
    elif idx in range(2, 6):
        print(["N", idx])
    else:
        print(["L", idx, i])
# Out:
# Referenzliste zum splitten und replacen; I=ID R=reference L=literal N=None
#
# refreplace für I und R, split für R, erst split dann refreplace
#
# ['I', 0, 'ID']
# ['L', 1, 'PR_Titel']
# ['N', 2]
# ['N', 3]
# ['N', 4]
# ['N', 5]
# ['R', 6, 'Produktionstyp']
# ['R', 7, 'Beteiligte_Gruppen']
# ['R', 8, 'Konzept']
# ['R', 9, 'Textbearbeitung']
# ['R', 10, 'Übersetzung']
# ['R', 11, 'Regie']
# ['R', 12, 'SprecherIn']
# ['R', 13, 'Choreographie']
# ['R', 14, 'Dramaturgie']
# ['R', 15, 'Bühnenbild']
# ['R', 16, 'Kostümdesgin']
# ['R', 17, 'Figurenbau']
# ['R', 18, 'Maskenbau']
# ['R', 19, 'Lichtdesign']
# ['R', 20, 'Videodesign']
# ['R', 21, 'Schauspieler']
# ['R', 22, 'Tänzer']
# ['R', 23, 'Darsteller']
# ['R', 24, 'Musiker']
# ['R', 25, 'Komposition']
# ['R', 26, 'Mitwirkende']
# ['L', 27, 'Premierendatum']
# ['L', 28, 'Dernierendatum']
# ['L', 29, 'Spielzeit_Start']
# ['L', 30, 'Spielzeit_Ende']
# ['R', 31, 'Veranstaltungsort']
# ['R', 32, 'Stadt']
# ['R', 33, 'Land']
# ['R', 34, 'Spielzeit']
# ['L', 35, 'BeschreibungQuelle']
# ['L', 36, 'Texte_Autoren']

# %%
pr_test = pr_clean.iloc[:, 6:27].apply(refreplace, axis=1)
## refreplace zwei mal mit splice, weil alle refs beieinander liegen, ansonsten könnte man auch mit
## [:, [0,3,4,12]] einzelne Spalten anwählen

# %%
pr_test
# Out:
#                          Produktionstyp  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                urauffuehrungsversion
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                urauffuehrungsversion
# 26                urauffuehrungsversion
# 27                urauffuehrungsversion
# 28                                  NaN
# 29                                  NaN
# ..                                  ...
# 68                                  NaN
# 69                                  NaN
# 70                                  NaN
# 71                                  NaN
# 72                                  NaN
# 73                                  NaN
# 74                                  NaN
# 75                                  NaN
# 76                                  NaN
# 77                                  NaN
# 78                urauffuehrungsversion
# 79                                  NaN
# 80                                  NaN
# 81                                  NaN
# 82                                  NaN
# 83                                  NaN
# 84                                  NaN
# 85                                  NaN
# 86                                  NaN
# 87                                  NaN
# 88                                  NaN
# 89                                  NaN
# 90                                  NaN
# 91                                  NaN
# 92                                  NaN
# 93                                  NaN
# 94                                  NaN
# 95                                  NaN
# 96                                  NaN
# 97  tschechoslowakische_erstauffuehrung
#
#                               Beteiligte_Gruppen  \
# 0                                      g_version
# 1                                            NaN
# 2                                            NaN
# 3                      g_pantomime_ensemble_jena
# 4                                            NaN
# 5                       g_theatre_regional_doran
# 6                     g_karls_kuehne_gassenschau
# 7                                            NaN
# 8          g_dt_pe_g_amateurstudio_g_4_litres_12
# 9                                            NaN
# 10                                       g_dt_pe
# 11                                    g_zinnober
# 12                                       g_dt_pe
# 13                                 g_griftheater
# 14                                g_salto_vitale
# 15                                 g_finke_faltz
# 16                                       g_dt_pe
# 17                                           NaN
# 18                                g_salto_vitale
# 19                                           NaN
# 20                    g_la_compagnie_les_fusains
# 21                                           NaN
# 22                                 g_alfred_spol
# 23                                   g_studio_61
# 24                                   g_studio_61
# 25                                       g_dt_pe
# 26                                       g_dt_pe
# 27                       g_dt_pe_g_amateurstudio
# 28                                           NaN
# 29                                    g_mimobile
# ..                                           ...
# 68                 g_actors_theatre_laboratorium
# 69                                g_salto_vitale
# 70                           g_werkhaus_moosbach
# 71                                           NaN
# 72                                   g_studio_61
# 73                                           NaN
# 74  g_the_snarling_beasties_g_the_birmingham_rep
# 75                                       g_dt_pe
# 76                                           NaN
# 77                                 g_finke_faltz
# 78                                       g_dt_pe
# 79                                       g_dt_pe
# 80                                           NaN
# 81                                           NaN
# 82                                           NaN
# 83                                       g_dt_pe
# 84                                           NaN
# 85                                       g_pt_pb
# 86                       g_theatre_de_l_ange_fou
# 87                            g_studio_pantomima
# 88                                           NaN
# 89                    g_pantomimen_studio_berlin
# 90                      g_studio_pantomime_sofia
# 91                       g_theater_an_der_schnur
# 92                    g_compagnia_teatro_dimitri
# 93                    g_compagnia_teatro_dimitri
# 94     g_stani_divadlo_brno_g_nositel_radu_prace
# 95     g_stani_divadlo_brno_g_nositel_radu_prace
# 96                                           NaN
# 97                                           NaN
#
#                                               Konzept Textbearbeitung  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                      peter_baumgart             NaN
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                    christian_mattis             NaN
# 8                                     gotthold_gloger             NaN
# 9                                    andras_m_kecskes             NaN
# 10                                                NaN             NaN
# 11                                                NaN             NaN
# 12                                                NaN             NaN
# 13                                                NaN             NaN
# 14                                                NaN             NaN
# 15                                                NaN             NaN
# 16                                                NaN             NaN
# 17                                                NaN             NaN
# 18                                                NaN             NaN
# 19                                     peter_baumgart             NaN
# 20                                                NaN             NaN
# 21                                     peter_baumgart             NaN
# 22                                                NaN             NaN
# 23                                                NaN             NaN
# 24                                                NaN             NaN
# 85     NaN                                                NaN
# 86     NaN                                                NaN
# 87     NaN                                                NaN
# 88     NaN                                     mitsuro_sasaki
# 89     NaN                                                NaN
# 90     NaN                                                NaN
# 91     NaN  jiri_pecha_vladimir_hauser_petr_malac_pavel_za...
# 92     NaN  szilard_szekely_esther_rietschin_joe_sebastian...
# 93     NaN  alberto_foletti_esther_rietschin_joe_sebastian...
# 94     NaN                                                NaN
# 95     NaN                                                NaN
# 96     NaN                                                NaN
# 97     NaN                                                NaN
#
#                                               Musiker  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   andreas_albrecht_tobias_dutschke_eckard_ewert_...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                       helm_gunnar_doelling_andreas
# 17                                   dietrich_petzold
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                   gundula_sonsalla
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                   dietrich_petzold
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                      hilprecht_uwe
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91  milos_stedron_iva_bittova_dagmar_jandova_dagma...
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                           Komposition  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                    dietrich_petzold
# 5                                    cheikh_abdelaoui
# 6                                                 NaN
# 7                                                 NaN
# 8                      uwe_hilprecht_dietrich_petzold
# 9           modest_petrowitsch_mussorgski_isao_tomita
# 10  hermann_naehring_dietrich_petzold_ruediger_phi...
# 11                                                NaN
# 12                                        nino_sandow
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                   dietrich_petzold
# 20                                                NaN
# 21                                   dietrich_petzold
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                   hermann_naehring
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                   dietrich_petzold
# 76                                                NaN
# 77                                                NaN
# 78                                  reiner_bredemeyer
# 79                                      uwe_hilprecht
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                  hans_otto_jerosch
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                      milos_stedron
# 92                                oliviero_giovannoni
# 93                                oliviero_giovannoni
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                           Mitwirkende
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   michel_willebrand_christoffer_petschow_falko_s...
# 4                                                 NaN
# 5   djelloul_abdelhak_said_missoum_abdelwahab_sala...
# 6                                                 NaN
# 7                                      johannes_knoth
# 8                                                 NaN
# 9                                                 NaN
# 10  monika_bienert_monika_kwiatkowski_karl_rhinow_...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  monika_bienert_karl_rhinow_klaus_rex_gerhard_h...
# 27  monika_bienert_hans_juergen_nikulka_karl_rhino...
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                 g_wroblewsky_m_klein_k_katzenstein
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78  monika_bienert_sabine_eckert_karl_rhinow_raine...
# 79  uwe_hilprecht_klaus_rex_gerhard_henschel_werne...
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                         iva_bittova_dagmar_jandova
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
# [98 rows x 21 columns]

# %%
pr_test
# Out:
#                                             ID  \
# 0                 pr_12_traeume_des_dr_fridkin
# 1                                   pr_amapola
# 2                                 pr_ameriques
# 3                      pr_aufstand_der_traeume
# 4                             pr_august_august
# 5                              pr_avat_theater
# 6                                 pr_baustelle
# 7                              pr_beauti_fools
# 8                pr_berliner_ballonfieber_1803
# 9                  pr_bilder_einer_ausstellung
# 10                                 pr_blaubart
# 11                   pr_bremer_stadtmusikanten
# 12                               pr_cafe_fatal
# 13                               pr_caoutchouc
# 14                      pr_carambolage_d_amour
# 15                             pr_clean_spleen
# 16                               pr_clownerien
# 17                               pr_clownonade
# 18                          pr_clowns_non_stop
# 19                             pr_clownsfamily
# 20                                pr_confusion
# 21                              pr_crazy_music
# 22                         pr_das_narrenschiff
# 23                        pr_der_erste_schritt
# 24                            pr_die_7schwaben
# 25                          pr_die_fremde_haut
# 26                          pr_die_verwandlung
# 27                pr_don_quichote_in_murzedelo
# 28                                 pr_egotrips
# 29  pr_es_regnet_langsam_ein_loch_in_die_nacht
# ..                                         ...
# 68                          pr_the_faust_quest
# 69                              pr_tief_in_uns
# 70                    pr_ueber_den_berg_kommen
# 71                        pr_ullyssee_ullyssee
# 72               pr_und_alle_haben_ein_gesicht
# 73               pr_unternehmen_straßentheater
# 74                                pr_valentino
# 75                          pr_verruecktwaerts
# 76           pr_viele_dinge_sind_in_einem_ding
# 77                               pr_vogelmogel
# 78        pr_von_kalaf_und_prinzessin_turandot
# 79        pr_wer_hat_angst_vorm_schwarzen_mann
# 80                               pr_wir_wohner
# 81                            pr_wir_wohner_ii
# 82                           pr_wir_wohner_iii
# 83                  pr_zwischen_tuer_und_angel
# 84                                pr_stadtgang
# 85                        pr_der_große_nepomuk
# 86                              pr_la_croisade
# 87                            pr_don_quichotte
# 88                        pr_human_powerflight
# 89                                pr_phantasie
# 90                                 pr_schatten
# 91                    pr_don_juan_und_genovefa
# 92              pr_aber_macht_keine_dummheiten
# 93                              pr_capitombola
# 94                                pr_traumwelt
# 95                           pr_silberner_wind
# 96                                   pr_svatba
# 97                       pr_horatier_kuriatier
#
#                                          Beschreibung
# 0   produktion des mime-theater "version" aus tsch...
# 1                                                 NaN
# 2                                                 NaN
# 3                                           mimodrama
# 4                                                 NaN
# 5   theaterstück in drei teilen "das netz oder der...
# 6   klamauk, akrobatik und artistik im baugerüst. ...
# 7   "beautifools" ist die meistgespielte, erfolgre...
# 8   weitere mitwirkende: kinder des ensembles und ...
# 9   pantomimensolo; als grundlage dafür dient die ...
# 10                                                NaN
# 11                                                NaN
# 12                                       uraufführung
# 13  in dieser produktion wir die bühne durch hunde...
# 14                                                NaN
# 15  in der neuesten produktion von finke/faltz ger...
# 16  lustige und ernste spiele von sechs clowns. fü...
# 17                                                NaN
# 18  in ihren ausgefeilten slapsticknummern verbind...
# 19                                                NaN
# 20  "confusion" beginnt mit szenen aus dem alltag....
# 21                                                NaN
# 22  die aus brettern gezimmerte bühne, mit seilen ...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  uraufführung. zweite produktion des pedt für k...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 68                                                NaN
# 69  programm von constanze debus und lutz jope des...
# 70  ein poetisches drama über die dichterin onono ...
# 71                                                NaN
# 72  abendprogramm des studio 61 unter der leitung ...
# 73                                                NaN
# 74  in dieser produktion kamen erstmals das zünden...
# 75                                                NaN
# 76                                                NaN
# 77  komisch-satirisches pantomimenprogramm, in dem...
# 78                                                NaN
# 79  die verwendeten texte und lieder stammen u.a. ...
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90  produktion des studio pantomima sofia, dramati...
# 91  "das rührende lesen über don juan und die unsc...
# 92                                                NaN
# 93  eine farce von liebe und verfall für drei musi...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97  textfassung von eberhard kube und herbert de l...
#
# [98 rows x 2 columns]
