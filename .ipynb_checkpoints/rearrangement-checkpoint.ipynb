# %%
import pandas as pd
import numpy as np

# %%
xl = pd.ExcelFile('./NVT_Metadatentabelle_MASTER.xlsm')

# %%
xl.sheet_names  # see all sheet names
# Out:
# ['Produktionen',
#  'Ereignisse',
#  'Objekte VIDEOS',
#  'Objekte TEXT',
#  'Objekte BILD',
#  'Objekte AUDIO',
#  '||_Personen',
#  '||_Gruppen_Ensembles',
#  '||_Veranstaltungsort',
#  '||_Städte',
#  '||_Länder',
#  'Sammlungen',
#  'Serie',
#  'TYPEN und GLOSSARE',
#  'Fragen und Dok',
#  'TODOs',
#  'Legende',
#  'Unterobjekt Beispiele',
#  'Übersicht']

# %%
## events = pd.read_excel('./NVT_Metadatentabelle_MASTER.xlsm', sheet_name='Ereignisse')

# %%
productions = pd.read_excel('./NVT_Metadatentabelle_MASTER.xlsm', sheet_name='Produktionen', header=1)

# %%
prclean = (productions[productions['Identifier / geeinigter Name'].str.contains('PR', na=False)] ## drops all rows that don't start with 'PR' or are NaN
           .drop(['Musik (für GEMA)'], axis='columns') ## drops unmodeled column
           .drop([2]) ## drops example row
           .reset_index(drop=True) ## resets index to be continouus
           .rename(columns={'Identifier / geeinigter Name':'ID', ## renames columns for future reference
                                          'Produktionsname / Titel':'PR_Titel',
                                          'Quelle (Beschreibung)':'Q_Beschreibung',
                                          'Verwendete Texte':'Verwendete_Texte',
                                          'Autor(en) der Texte':'Autoren_Texte',
                                          'Beteiligte Gruppen / Compagnies':'Beteiligte_Gruppen',
                                          'Sprecher*in':'SprecherIn',
                                          'Darsteller allgem.':'Darsteller',
                                          'Weitere Mitwirkende':'Mitwirkende',
                                          'Spielzeit / Laufzeit Start':'Spielzeit_Start',
                                          'Spielzeit / Laufzeit Ende':'Spielzeit_Ende'
}))

# %%
prclean.head()
# Out:
#                              ID                   PR_Titel  \
# 0  PR_12_Traeume_des_Dr_Fridkin  12 Träume des Dr. Fridkin
# 1                    PR_Amapola                    Amapola
# 2                  PR_Ameriques                  Ameriques
# 3       PR_Aufstand_der_Traeume        Aufstand der Träume
# 4              PR_August_August             August, August
#
#                                         Beschreibung  \
# 0  Produktion des Mime-Theater "Version" aus Tsch...
# 1                                                NaN
# 2                                                NaN
# 3                                          Mimodrama
# 4                                                NaN
#
#                                       Q_Beschreibung     Verwendete_Texte  \
# 0  TN; Programmheft Woche des Gestischen Theaters...                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN  Aufstand der Träume
# 4                                                NaN                  NaN
#
#           Autoren_Texte Produktionstyp         Beteiligte_Gruppen  \
# 0                   NaN            NaN                  G_Version
# 1  Omar_Saavedra,Santis            NaN                        NaN
# 2                   NaN            NaN                        NaN
# 3        Andreas,Ittner            NaN  G_Pantomime_Ensemble_Jena
# 4                   NaN            NaN                        NaN
#
#           Konzept Textbearbeitung  ... Musiker       Komposition  \
# 0             NaN             NaN  ...     NaN               NaN
# 1             NaN             NaN  ...     NaN               NaN
# 2             NaN             NaN  ...     NaN               NaN
# 3             NaN             NaN  ...     NaN               NaN
# 4  Peter,Baumgart             NaN  ...     NaN  Dietrich,Petzold
#
#                                          Mitwirkende Premierendatum  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3  Michel,Willebrand;Christoffer,Petschow;Falko,S...            NaN
# 4                                                NaN            NaN
#
#   Dernierendatum Spielzeit_Start Spielzeit_Ende Veranstaltungsort  \
# 0            NaN             NaN            NaN               NaN
# 1            NaN             NaN            NaN               NaN
# 2            NaN             NaN            NaN               NaN
# 3            NaN             NaN            NaN               NaN
# 4            NaN             NaN            NaN               NaN
#
#            Stadt   Land
# 0  Tscheljabinsk  UDSSR
# 1            NaN    NaN
# 2            NaN    NaN
# 3           Jena    DDR
# 4            NaN    NaN
#
# [5 rows x 34 columns]
